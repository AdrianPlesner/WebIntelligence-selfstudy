# %% [markdown]
# # Self Study 3

# %% [markdown]
# This self study concludes our first "miniproject" on crawling and search. The tasks for this self study are:
# - modify/extend the inverted index you constructed in the previous self study to contain for all postings the term frequencies (if your documents are just the titles of the web pages, you will see very few term frequencies larger than 1, but do not worry about that).
# - calculate the idf values for all terms, and also include them in your index (cf. slide 3.20 for a schematic view)
# - implement ranked retrieval as described on slides 3.19 and 3.20 for the ntc.bnc similarity metric

# %%
import requests
from bs4 import BeautifulSoup
from urllib.robotparser import RobotFileParser
import random
import nltk
nltk.download('punkt')
from queue import SimpleQueue as Queue
from datetime import datetime
from datetime import timedelta
import json
import math
import numpy as np
ps=nltk.PorterStemmer()

def enqueue(qlist, obj):
    i = random.randint(0, len(qlist) -1)
    qlist[i].put(obj)

def extract_domain(url):
    s = url.split("/")
    return s[2]

def get_crawl(qd):
    result = None
    keys = list(qd)
    i = 0
    sec2 = timedelta(0,2)
    while result is None and i < len(keys):
        key = keys[i]
        if not qd[key]['queue'].empty() and datetime.now() > qd[key]['time']:
            result = qd[key]['queue'].get()
            qd[key]['time'] = datetime.now() + sec2

        else:
            i += 1
    return result


def idf(term, idx):
    if term in idx.keys():
        return math.log10( len(idx) / len(idx[term]))
    else:
        return 0
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Bruger\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
seed = ["https://pinchofyum.com/", "https://loveandlemons.com/","https://imdb.com/", "https://gamegrumps.com/"]
frontier = []
for i in range(10):
    frontier.append(Queue())
for s in seed:
    enqueue(frontier, s)

visited = []
results = []
index = 0
backQ = {}
while len(results) < 1000:
    s = random.random()
    if s > 0.5:
        print(f'index size is now {index}')
    rp=RobotFileParser()
    next_url = get_crawl(backQ)
    if not backQ or get_crawl(backQ) is None:
        for i in range(len(frontier)-1):
            f = frontier[i]
            while not f.empty():
                url = f.get()
                domain = extract_domain(url)
                if domain not in backQ.keys():
                    backQ[domain] = {'time': datetime.now(), 'queue': Queue()}
                backQ[domain]['queue'].put(url)

    else:
        try:
            if next_url in visited or next_url is None:
                continue
            print('crawling at ' + next_url)
            rp.set_url(next_url)
            rp.read()

            if rp.can_fetch("*", next_url):
                r=requests.get(next_url)
                visited.append(next_url)
                r_parse = BeautifulSoup(r.text, 'html.parser')
                title = r_parse.find('title')
                if title is not None:
                    title = title.string
                    text = r_parse.get_text()
                    tokens = nltk.word_tokenize(title)
                    tokens.extend(nltk.word_tokenize(text))
                    toks = []
                    for token in tokens:
                        toks.append(ps.stem(token))
                    slup = {'url': next_url, 'title': title, 'tokens': toks, 'id': index}
                    print(f'adding {next_url} to index')
                    index += 1
                    results.append(slup)
                    for a in r_parse.find_all('a'):
                        if 'href' in a.attrs:
                            l = a['href']
                            if l.startswith('https') and l not in visited:
                                enqueue(frontier, l)
            else:
                print('could not crawl at ' + next_url)
        except:
            print(f'woops at {next_url}')

# %%
len(results)
# Out:
# 1000

# %%
inv_index = {}
for e in results:
    d = {}
    for t in e['tokens']:
        if t in d.keys():
            d[t] += 1
        else:
            d[t] = 1
    for k in d:
        if k in inv_index.keys():
            inv_index[k][e['id']] = d[k]
        else:
            inv_index[k] = {e['id']: d[k]}

# %%
print(len(inv_index))
# Out:
# 50284

# %%
len(results)
# Out:
# 1000

# %%
with open("inverted_index.json", "w") as outfile:
    json.dump(inv_index, outfile)

# %%
with open("crawled.json", "w") as outfile:
    json.dump(results, outfile)

# %%
with open("crawled.json", "r") as infile:
          crawled = json.load(infile)
          
with open("inverted_index.json", "r") as infile:
          inv_index = json.load(infile)

# %%
def search(query):
    words = query.split(" ")
    stemmed = []
    for w in words:
        stemmed.append(ps.stem(w))
    words = np.array(stemmed)
    
    docs = {}
    i = 0
    for w in words:
        if w in inv_index.keys():
            d = inv_index[w]
            for k in d.keys():
                if k != '*idf':
                    if k not in docs.keys():
                        docs[k] = np.zeros(len(words))
                    docs[k][i] = d[k] * d['*idf']
        i += 1
    for k in docs.keys():
        v = docs[k]
        vlen = np.sqrt(np.sum(np.apply_along_axis(lambda x: x**2,0, v)))
        docs[k] = v / vlen
    results = []
    words = np.ones(len(words))
    wlen = np.sqrt(np.sum(np.apply_along_axis(lambda x: x**2,0, words)))
    words = words /wlen
    for k in docs.keys():
        results.append((k, np.dot(docs[k], words)))
    results.sort(reverse=True, key=lambda x: x[1])
    results = results[:10]
    print(results)
    rep = []
    for i in range(len(results)):
        t = int(results[i][0])
        rep.append(crawled[t]['url'])
    return rep

# %%
search("yeast")
# Out:
# [('18', 1.0), ('27', 1.0), ('235', 1.0), ('237', 1.0), ('352', 1.0), ('486', 1.0), ('560', 1.0), ('563', 1.0), ('589', 1.0), ('651', 1.0)]
# ['https://www.loveandlemons.com/summer-appetizers/',
#  'https://www.loveandlemons.com/love-lemons-cooking-club-september/',
#  'https://www.loveandlemons.com/vegan-recipes/',
#  'https://www.loveandlemons.com/appetizers/',
#  'https://www.loveandlemons.com/cashew-cream/',
#  'https://www.loveandlemons.com/vegan-mac-and-cheese/',
#  'https://www.loveandlemons.com/dinner-rolls-recipe/',
#  'https://www.loveandlemons.com/no-knead-bread-recipe/',
#  'https://www.loveandlemons.com/vegan-cheese/',
#  'https://www.loveandlemons.com/soft-pretzels-recipe/']

# %%
vec = np.array([1,2,3])
vlen = np.sqrt(np.sum(np.apply_along_axis(lambda x: x**2,0, vec)))
ne = vec / vlen
np.sqrt(np.sum(np.apply_along_axis(lambda x: x**2,0, ne)))
# Out:
# 1.0

# %%
b = {'a': 100, 'b': 2, 'c': 3}
max(b, key=lambda key: b[key])
# Out:
# 'a'

# %%
for c in crawled:
    print(c['url'])
# Out:
# https://loveandlemons.com/
# https://imdb.com/
# https://www.loveandlemons.com/jalapeno-cornbread/
# https://instagram.com/imdb
# https://www.loveandlemons.com/honey-butter/
# https://www.instagram.com/loveandlemons/
# https://www.loveandlemons.com/baked-potato/
# https://pro.imdb.com/login/ap?u=/login/lwa&imdbPageAction=signUp&rf=cons_nb_hm&ref_=cons_nb_hm
# https://www.facebook.com/lovelemonsfood
# https://twitch.tv/IMDb
# https://www.loveandlemons.com/healthy-wraps/
# https://contribute.imdb.com/czone?ref_=nv_cm_cz
# https://m.imdb.com/chart/starmeter/?ref_=nv_cel_brn
# https://www.loveandlemons.com/granola/
# https://help.imdb.com/imdb
# https://instagram.com/loveandlemons/
# https://www.pinterest.com/loveandlemons/
# https://www.boxofficemojo.com
# https://www.loveandlemons.com/summer-appetizers/
# https://pro.imdb.com/login/imdb?u=https%3A%2F%2Fpro.imdb.com%2Flogin%2Flwa%3Frf%3Dcons_nb_hm%26ref_%3Dcons_nb_hm&rf=cons_nb_hm
# https://www.loveandlemons.com/falafel/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fbaked-potato%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F04%2Fbaked-potato-pin-1.jpg&description=&is_video=false
# https://youtube.com/imdb/
# https://m.imdb.com/feature/bestpicture/?ref_=nv_ch_osc
# https://www.loveandlemons.com/hummus-recipe/
# https://pro.imdb.com/signup/index.html?rf=helpms_helpftr_joinpro&ref_=helpms_helpftr_joinpro
# https://advertising.amazon.com/resources/ad-specs/imdb/
# https://www.loveandlemons.com/love-lemons-cooking-club-september/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fhealthy-wraps%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F09%2Fhealthy-wraps-pin.jpg&description=&is_video=false
# https://pro.imdb.com?ref_=cons_nb_hm&rf=cons_nb_hm
# https://www.loveandlemons.com/ratatouille-recipe/
# https://help.imdb.com/article/imdb/general-information/imdb-site-index/GNCX7BHNSPBTFALQ#so
# https://www.facebook.com/recover/initiate/?ars=facebook_login
# https://slyb.app.link/SKdyQ6A449
# https://help.imdb.com/login/pro?rf=helpms_login_popup_pro&u=%2Fimdb&ref_=helpms_login_popup_pro
# https://tr-tr.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Flovelemonsfood
# https://about.instagram.com/about-us/careers
# https://www.loveandlemons.com/butternut-squash-soup/
# https://pro.imdb.com/signup/index.html?ref_=cons_cntrbt_cz&rf=cons_cntrbt_cz
# https://help.imdb.com/?ref_=helphdr_helphome
# https://www.loveandlemons.com/eggplant-parmesan/
# https://www.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Flovelemonsfood
# https://community-imdb.sprinklr.com/
# https://www.loveandlemons.com/easy-dinner-ideas/
# https://ar-ar.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Flovelemonsfood
# https://de-de.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Flovelemonsfood
# https://fo-fo.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Flovelemonsfood
# https://www.loveandlemons.com/brunch-recipes/
# https://www.facebook.com/help/568137493302217
# https://www.imdb.com/calendar/?ref_=nv_mv_cal
# https://www.loveandlemons.com/roasted-broccoli/
# https://www.instagram.com/developer/
# https://www.imdb.com/search/name/?match_all=true&ref_=nv_cel_m
# https://www.loveandlemons.com/baked-sweet-potato/
# https://www.imdb.com/what-to-watch/?ref_=helpms_ih_gi_siteindex
# https://www.instagram.com/legal/terms/
# https://www.loveandlemons.com/how-to-cook-brown-rice/
# https://www.loveandlemons.com/how-to-cook-lentils/
# https://www.instagram.com/legal/privacy/
# https://www.loveandlemons.com/blueberry-pancakes/
# https://www.instagram.com/imdb/?ref_=helpms_ih_gi_siteindex
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Feggplant-parmesan%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2020%2F02%2Feggplant-parmesan-pin.jpg&description=&is_video=false
# https://www.facebook.com/watch/
# https://advertising.amazon.com/resources/ad-specs/imdb/mobile-banner?ref_=a20m_us_ispc_mpb
# https://www.loveandlemons.com/healthy-meal-prep-ideas/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Feasy-dinner-ideas%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2020%2F01%2Fdinner-ideas-pin.jpg&description=Need+some+new+easy+dinner+ideas%3F+Find+5+great+strategies+for+getting+a+healthy+dinner+on+the+table+in+no+time%2C+plus+plenty+of+recipes+to+guide+you+along+the+way%21+%7C+Love+and+Lemons+%23mealprep+%23mealplanning+%23dinnerrecipes+%23healthydinner+%23healthyrecipes+%23vegetarian&is_video=false
# https://pro.imdb.com/
# https://www.loveandlemons.com/fruit-platter/
# https://contribute.imdb.com/times?ref_=helpms_ih_gi_siteindex
# https://www.instagram.com/amazonads/
# https://pay.facebook.com/
# https://www.instagram.com/imdb
# https://www.facebook.com/BoxOfficeMojo/
# https://pt-br.facebook.com/login/identify/?ctx=recover&ars=facebook_login&from_login_screen=0
# https://www.loveandlemons.com/vegan-sandwiches/
# https://www.instagram.com/imdbpro
# https://www.facebook.com/imdbpro
# https://help.imdb.com/article/imdb/discover-watch/how-can-i-watch-a-movie-or-tv-show/G4GAAPL3XS2E99KY?ref_=__seemr
# https://www.facebook.com/AmazonAds/
# https://pt-br.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Flovelemonsfood
# https://ro-ro.facebook.com/login/identify/?ctx=recover&ars=facebook_login&from_login_screen=0
# https://es-la.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Flovelemonsfood
# https://www.loveandlemons.com/how-to-cook-spaghetti-squash/
# https://pro.imdb.com/?ref_=header
# https://advertising.amazon.com/resources/ad-specs/imdb/rect?ref_=a20m_us_ispc_rctn
# https://www.loveandlemons.com/roasted-butternut-squash/
# https://pro.imdb.com/content/featured?rf=cons_cntrbt_cz&ref_=spl_rsrc_nav
# https://help.imdb.com/article/imdb/general-information/why-do-i-need-to-enable-my-cookies-on-imdb/GWE3JQ8VUQDCFW3Q?ref_=helpsect_contrib_1_6
# https://www.loveandlemons.com/how-to-make-cauliflower-rice/
# https://pro.imdb.com/?rf=cons_cntrbt_cz&ref_=spl_stkyhdr_i
# https://help.imdb.com/article/imdb/featured-content/why-doesn-t-a-title-with-the-average-user-vote-of-9-4-appear-in-your-top-250-movies-or-tv-list/GTU67Q5QQ8W53RJT?ref_=helpsect_contrib_4_1
# https://pl-pl.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Flovelemonsfood
# https://www.amazon.jobs/en/teams/imdb?ref_=helpms_ih_gi_siteindex
# https://help.imdb.com/article/imdb/mobile-web-apps/mobile-site-faq/GQN2XBEU8UM9PZ8T?ref_=helpsect_contrib_7_4
# https://pro.imdb.com/login/auth?u=%2Flogin%2Flwa&imdbPageAction=signup&rf=cons_cntrbt_cz&ref_=spl_bene_signup
# https://advertising.amazon.com/resources/ad-specs/imdb/standard-takeover?ref_=a20m_us_ispc_sdto
# https://www.loveandlemons.com/tomato-basil-soup-recipe/
# https://advertising.amazon.com/resources/ad-specs/imdb/mobile-video-wall?ref_=a20m_us_ispc_mvw
# https://advertising.amazon.com/resources/ad-specs/imdb/media-viewer-banner?ref_=a20m_us_ispc_mvb
# https://ro-ro.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Flovelemonsfood
# https://advertising.amazon.com/resources/ad-specs/imdb/email?ref_=a20m_us_ispc_emb
# https://www.amazon.jobs/team-category/advertising?ref_=a20m_us_fnav_l_cars
# https://www.amazon.jobs/teams/imdb?ref_=helpms_helpftr_jobs
# https://advertising.amazon.com/resources/ad-specs/imdb/premium-takeover?ref_=a20m_us_ispc_pmto
# https://about.facebook.com/
# https://advertising.amazon.com/resources/ad-specs/imdb/promoted-video?ref_=a20m_us_ispc_prvd
# https://advertising.amazon.com/resources/ad-specs/imdb/premium-name-page?ref_=a20m_us_ispc_pnp
# https://www.loveandlemons.com/blt-pasta-salad/
# https://advertising.amazon.com/resources/ad-specs/imdb/tablet-banner?ref_=a20m_us_ispc_ldbb
# https://facebook.com/imdb
# https://advertising.amazon.com/resources/ad-specs/imdb/interstitial?ref_=a20m_us_ispc_int
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fbaked-sweet-potato%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2020%2F02%2Fbaked-sweet-potato-pin.jpg&description=&is_video=false
# https://instagram.com/cedarsfoods/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fblt-pasta-salad%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F08%2Fblt-pasta-salad-pin.jpg&description=&is_video=false
# https://pro.imdb.com/login/auth?u=%2Flogin%2Flwa&imdbPageAction=signup&rf=helpms_helpftr_joinpro&ref_=spl_hero_signup
# https://instagram.com/seedandmill
# https://www.pinterest.com/soomfoods/_created/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fhow-to-cook-lentils%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F04%2Flentils-pin-1.jpg&description=&is_video=false
# https://www.facebook.com/payments_terms
# https://www.loveandlemons.com/blueberry-muffins/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fvegan-sandwiches%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F09%2Fvegan-sandwiches-pin.jpg&description=&is_video=false
# https://www.facebook.com/payments_terms/privacy
# https://www.instagram.com/jellyskateboards
# https://www.loveandlemons.com/avocado-recipes/
# https://pro.imdb.com?ref_=ft_pro&rf=cons_tf_pro
# https://www.loveandlemons.com/tempeh/
# https://www.instagram.com/thebridestory
# https://developer.imdb.com/
# https://help.imdb.com/article/imdb/track-movies-tv/watchlist-faq/G9PA556494DM8YBA?ref_=helpsect_contrib_2_2
# https://www.instagram.com/instagramforbusiness
# https://www.instagram.com/about/jobs/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Froasted-butternut-squash%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2019%2F12%2Fbutternut-squash-pin.jpg&description=&is_video=false
# https://help.imdb.com/article/imdb/discover-watch/imdb-tv-faq/GZML3SK6UQK8EMYV?ref_=helpsect_contrib_3_2
# https://pt-br.facebook.com/watch/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Ftomato-basil-soup-recipe%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2020%2F09%2Ftomato-basil-soup-pin.jpg&description=&is_video=false
# https://advertising.amazon.com/resources/ad-specs/imdb/premium-billboard?ref_=a20m_us_prmtkv_prmblbr
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fhealthy-meal-prep-ideas%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2019%2F02%2Fhealthy-meal-prep-ideas-pin.jpg&description=&is_video=false
# https://pro.imdb.com/industrynews?rf=helpms_helpftr_joinpro&ref_=spl_newslp_nav
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fquinoa%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2019%2F05%2Fquinoa-pin.jpg&description=&is_video=false
# https://advertising.amazon.com/resources/ad-specs/imdb/premium-billboard?ref_=a20m_us_prmtkv_spec_prmblbr
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Ffruit-tart%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F08%2Ffruit-tart-pin.jpg&description=&is_video=false
# https://advertising.amazon.com/resources/ad-specs/?ref_=a20m_us_hnav_spcs
# https://www.pinterest.com/cedars_foods/
# https://www.instagram.com/insideamazon/?Amazon.jobs=footer
# https://help.imdb.com/contribution?ref_=contrib_ftr_help
# https://www.instagram.com/gayprideapparel/
# https://www.facebook.com/business/learn/courses/instagram?ref=igb
# https://www.loveandlemons.com/salad-recipes/
# https://www.facebook.com/business/marketing/messenger
# https://www.loveandlemons.com/simple-roasted-beets/
# https://www.instagram.com/p/CHWHhcdpjbE/
# https://www.loveandlemons.com/how-to-cook-tofu/
# https://www.facebook.com/help/396404120401278/list
# https://help.imdb.com/article/imdb/general-information/imdb-login-registration-issues/G33ZSB53EE6KVHMP?ref_=helpsect_pro_1_5
# https://www.instagram.com/about/legal/privacy/
# https://www.loveandlemons.com/zucchini-noodles/
# https://www.facebook.com/login/identify/?ctx=recover&ars=facebook_login&from_login_screen=0
# https://help.imdb.com/article/imdb/track-movies-tv/weighted-average-ratings/GWT2DSBYVT2F25SK?ref_=helpsect_pro_2_8
# https://www.instagram.com/soomfoods/?hl=en
# https://pt-br.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FAmazonAds%2F
# https://www.facebook.com/InsideAmazon/?Amazon.jobs=footer
# https://help.imdb.com/article/imdb/discover-watch/what-to-watch-faq/GPZ2RSPB3CPVL86Z?ref_=helpsect_pro_3_8
# https://www.facebook.com/policies/?ref=pf
# https://help.imdb.com/article/imdb/mobile-web-apps/android-app-faq/G8LZ824YMXLJ8URG?ref_=helpsect_pro_7_1
# https://pt-br.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FBoxOfficeMojo%2F
# https://pl-pl.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FBoxOfficeMojo%2F
# https://help.imdb.com/article/imdb/general-information/site-preferences/GDL9NWJRKWRH5L6K?ref_=helpsect_cons_1_3
# https://www.instagram.com/qantas
# https://www.facebook.com/CedarsFoods/?fref=ts
# https://help.imdb.com/article/imdb/general-information/why-do-i-need-to-enable-my-cookies-on-imdb/GWE3JQ8VUQDCFW3Q?ref_=helpsect_cons_1_6
# https://www.instagram.com/gatorade
# https://www.facebook.com/dialog/feed?app_id=9869919170&link=https%3A%2F%2Fwww.nytimes.com%2F2006%2F12%2F31%2Ftravel%2F31bite.html%3Fsmid%3Dfb-share&name=%20Paris%3A%20L%E2%80%99As%20du%20Fallafel&redirect_uri=https%3A%2F%2Fwww.facebook.com%2F
# https://help.imdb.com/article/imdb/track-movies-tv/lists-faq/GNQMN47VZSE7KW38?ref_=helpsect_cons_2_1
# https://pt-br.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdb
# https://www.facebook.com/policy.php/
# https://www.instagram.com/reframe_project/
# https://help.imdb.com/article/imdb/track-movies-tv/how-do-i-submit-my-rating-on-imdb/G9R8NF943K39DQDT?ref_=helpsect_cons_2_3
# https://pro.imdb.com/?ref_=helpms_helpftr_pro
# https://advertising.amazon.com/resources/ad-specs/?ref_=a20m_us_fnav_spcs
# https://pro.imdb.com/inproduction/development?dev&ref_=mojo_rs_procta&rf=mojo_rs_procta#type=movie&status=DEVELOPMENT,PRE_PRODUCTION,PRODUCTION,POST_PRODUCTION&sort=ranking
# https://advertising.amazon.com/resources/ad-specs/imdb/tablet-banner?ref_=a20m_us_prmtkv_ldbrd
# https://pro.imdb.com/company/co0049592/boxoffice/?view=releases&ref_=mojo_rs_table_5&rf=mojo_rs_table_5
# https://tr-tr.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdbpro
# https://about.instagram.com/blog/
# https://pro.imdb.com/company/co0026545/boxoffice/?view=releases&ref_=mojo_rs_table_12&rf=mojo_rs_table_12
# https://pro.imdb.com/company/co0002663/boxoffice/?view=releases&ref_=mojo_rs_table_13&rf=mojo_rs_table_13
# https://tr-tr.facebook.com/login/identify/?ctx=recover&ars=facebook_login&from_login_screen=0
# https://www.amazon.com/adlp/imdbtv-about?ref_=helpms_ih_dw_tv
# https://www.loveandlemons.com/healthy-breakfast-ideas/
# https://pro.imdb.com/title/tt14505430?ref_=mojo_rs_table_15&rf=mojo_rs_table_15
# https://advertising.amazon.com/resources/ad-specs/imdb/rect?ref_=a20m_us_spcs_imdb_sdto_rct
# https://www.loveandlemons.com/healthy-lunch-ideas/
# https://pro.imdb.com/title/tt9857480?ref_=mojo_rs_table_18&rf=mojo_rs_table_18
# https://advertising.amazon.com/resources/ad-specs/imdb/tablet-banner?ref_=a20m_us_spcs_imdb_sdto_tblb
# https://www.loveandlemons.com/vegan-recipes/
# https://pro.imdb.com/title/tt6910282?ref_=mojo_rs_table_22&rf=mojo_rs_table_22
# https://www.loveandlemons.com/appetizers/
# https://pro.imdb.com/company/co0000756/boxoffice/?view=releases&ref_=mojo_rs_table_23&rf=mojo_rs_table_23
# https://www.loveandlemons.com/farro/
# https://pro.imdb.com/?ref_=helpms_helphdr_pro
# https://es-la.facebook.com/login/identify/?ctx=recover&ars=facebook_login&from_login_screen=0
# https://ar-ar.facebook.com/login/identify/?ctx=recover&ars=facebook_login&from_login_screen=0
# https://pro.imdb.com/subagreement?ref_=helpms_helpftr_subagr
# https://de-de.facebook.com/login/identify/?ctx=recover&ars=facebook_login&from_login_screen=0
# https://es-la.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FAmazonAds%2F
# https://ar-ar.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdbpro
# https://play.google.com/?hl=da
# https://ro-ro.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FBoxOfficeMojo%2F
# https://es-la.facebook.com/watch/
# https://de-de.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdbpro
# https://fo-fo.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FAmazonAds%2F
# https://pro.imdb.com/groupplan?ref_=spl_pricing_gp
# https://www.amazon.com/imdbtv?ref_=helpms_ih_dw_tvFAQ
# https://es-la.facebook.com/help/568137493302217
# https://pro.imdb.com/?ref_=spl_ftr_hm_i
# https://ro-ro.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FAmazonAds%2F
# https://about.facebook.com/news/2021/08/introducing-horizon-workrooms-remote-collaboration-reimagined/
# https://advertising.amazon.com/resources/ad-specs/imdb/rect?ref_=a20m_us_prmtkv_rctn
# https://www.loveandlemons.com/soup-recipes/
# https://www.amazon.com/gp/help/customer/display.html/?ie=UTF8&nodeId=GKE2YYEA6GB62ULS&ref_=helpms_ih_dw_tv
# https://ro-ro.facebook.com/watch/
# https://about.facebook.com/news/2021/08/asking-people-for-their-birthday-on-instagram/
# https://pro.imdb.com/login/ap?u=%2Flogin%2Flwa&imdbPageAction=signUp&ref_=mojo_nb_frs_rollover&rf=mojo_nb_frs_rollover
# https://ro-ro.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdb
# https://www.amazon.jobs/en/teams/imdb
# https://pro.imdb.com/title/tt8231202?ref_=mojo_rs_table_2&rf=mojo_rs_table_2
# https://ro-ro.facebook.com/help/568137493302217
# https://pro.imdb.com/company/co0427244/boxoffice/?view=releases&ref_=mojo_rs_table_2&rf=mojo_rs_table_2
# https://help.instagram.com/
# https://pro.imdb.com/company/co0248867/boxoffice/?view=releases&ref_=mojo_rs_table_4&rf=mojo_rs_table_4
# https://pro.imdb.com/title/tt14857602?ref_=mojo_rs_table_11&rf=mojo_rs_table_11
# https://fo-fo.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FBoxOfficeMojo%2F
# https://business.instagram.com/success/?blog_page=2
# https://pro.imdb.com/title/tt9812474?ref_=mojo_rs_table_16&rf=mojo_rs_table_16
# https://facebook.com/ads/create
# https://pro.imdb.com/title/tt4244994?ref_=mojo_rs_table_23&rf=mojo_rs_table_23
# https://facebook.com/recover/initiate/?ref=www_reauth_page
# https://pro.imdb.com/?ref_=mojo_ft_rs_prologo&rf=mojo_ft_rs_prologo
# https://facebook.com/seedandmill
# https://fr-fr.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdbpro
# https://www.seedandmill.com/collections/tahini/products/organic-zaatar-tahini
# https://www.amazon.com/adprefs/imdb?ref_=helpms_ih_dw_adfreq
# https://www.amazon.com/gp/help/contact-us/digital-video.html?ref_=IMDbhelpms_ih_dw_tv
# https://about.facebook.com/news/2021/09/introducing-ray-ban-stories-smart-glasses/
# https://help.instagram.com/1554245014870700/
# https://advertising.amazon.com/resources/ad-specs/imdb/rect?ref_=a20m_us_prmtkv_spec_rctn
# https://pro.imdb.com/login/auth?u=https%3A%2F%2Fpro.imdb.com%2F
# https://pro.imdb.com/login/auth?u=%2Flogin%2Flwa&imdbPageAction=signup&ref_=spl_pricing_signup&pf_rd_r=GMGQZSGNSYHXWYNS2SWB&pf_rd_s=center-12&pf_rd_i=splash&pf_rd_t=43801&pf_rd_p=d9eb4598-5762-4c7e-bf71-3f897e61e64b
# https://pro.imdb.com/subagreement?ref_=spl_ftr_subagree
# https://help.imdb.com/article/imdb/social/check-ins-faq/GG59ELYW45FMC7J3?ref_=helpsect_pro_5_1
# https://fo-fo.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdbpro
# https://pro.imdb.com/?ref_=spl_stkyhdr_i
# https://help.imdb.com/article/imdb/mobile-web-apps/ios-app-faq/GJ7P484D8FA9C48Q?ref_=helpsect_pro_7_2
# https://advertising.amazon.com/resources/ad-specs/imdb/billboard?ref_=a20m_us_spcs_imdb_sdto_sdbb
# https://help.imdb.com/article/imdb/discover-watch/how-can-i-watch-a-movie-or-tv-show/G4GAAPL3XS2E99KY?ref_=helpsect_cons_3_1
# https://fr-fr.facebook.com/login/identify/?ctx=recover&ars=facebook_login&from_login_screen=0
# https://www.seedandmill.com
# https://help.imdb.com/article/imdb/general-information/site-preferences/GDL9NWJRKWRH5L6K?ref_=helpsect_contrib_1_3
# https://help.instagram.com/581066165581870
# https://www.oculus.com/blog/
# https://about.facebook.com/news/
# https://www.oculus.com/vr-for-good/
# https://help.imdb.com/article/imdb/track-movies-tv/how-do-i-sort-my-ratings-by-the-title-type/G4LHN2ZSCPNM5W2S?ref_=helpsect_contrib_2_7
# https://developers.facebook.com/?ref=pf
# https://help.imdb.com/article/imdb/track-movies-tv/weighted-average-ratings/GWT2DSBYVT2F25SK?ref_=helpsect_contrib_2_8
# https://accounts.google.com/TOS?loc=DK&hl=da&privacy=true
# https://itunes.apple.com/us/genre/id6016
# https://help.imdb.com/article/imdb/general-information/site-preferences/GDL9NWJRKWRH5L6K?ref_=helpsect_pro_1_3
# https://www.oculus.com/experiences/quest/
# https://help.imdb.com/article/imdb/track-movies-tv/lists-faq/GNQMN47VZSE7KW38?ref_=helpsect_pro_2_1
# https://www.oculus.com/quest-2-referrals/
# https://help.imdb.com/article/imdb/track-movies-tv/how-do-i-sort-my-ratings-by-the-title-type/G4LHN2ZSCPNM5W2S?ref_=helpsect_pro_2_7
# https://accounts.google.com/ServiceLogin?hl=da&continue=https://policies.google.com/terms?hl%3Dda%26utm_source%3Ducb
# https://www.ez.insure/landing/professional-liability/
# https://help.imdb.com/article/imdb/general-information/imdb-login-registration-issues/G33ZSB53EE6KVHMP?ref_=helpsect_cons_1_5
# https://www.nytimes.com/section/todayspaper
# https://portal.facebook.com/
# https://www.loveandlemons.com/roasted-chickpeas/
# https://help.imdb.com/article/imdb/general-information/what-is-imdb/G836CY29Z4SGNMK5?ref_=helpsect_contrib_1_1
# https://www.reframeproject.org/stamp
# https://www.loveandlemons.com/sweet-potato-salad-recipe/
# https://help.imdb.com/article/imdb/track-movies-tv/how-can-i-see-all-my-ratings/G6ZD78VKHTP4YTB3?ref_=helpsect_contrib_2_5
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fvegetarian-chili-recipe%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2019%2F05%2Fvegetarian-chili-pin.jpg&description=&is_video=false
# https://advertising.amazon.com/resources/ad-specs/custom-media/?ref_=a20m_us_spcs_nsm
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Froasted-brussels-sprouts%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F04%2Fbrussels-sprouts-pin-1.jpg&description=&is_video=false
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fcarrot-cake-cookies%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F04%2Fcarrot-cake-cookies-pin-1.jpg&description=&is_video=false
# https://contribute.imdb.com/updates?edit=co0000756&ref_=pro_co_pub_edit
# https://www.loveandlemons.com/caesar-salad/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fvegan-mac-and-cheese%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2020%2F03%2Fvegan-mac-and-cheese-pin.jpg&description=&is_video=false
# https://www.facebook.com/policies
# https://contribute.imdb.com/updates?edit=tt8231202&ref_=pro_tt_pub_edit
# https://www.loveandlemons.com/brownies-recipe/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Favocado-recipes%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2019%2F12%2Favocado-recipes-pin.jpg&description=&is_video=false
# https://www.facebook.com/help/1297502253597210?ref=dp
# https://contribute.imdb.com/updates?edit=co0248867/filmography&ref_=pro_co_pub_filmo_edit
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Ftempeh%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2020%2F01%2Ftempeh-pin.jpg&description=Learn+how+to+cook+tempeh+perfectly+every+time%21+Then%2C+find+20%2B+healthy+recipes+to+use+this+delicious+plant-based+protein.+%7C+Love+and+Lemons+%23tempeh+%23vegan+%23meatless+%23vegetarian&is_video=false
# https://www.facebook.com/settings/facerec
# https://contribute.imdb.com/updates?update=tt14505430:production_companies/distributors/special_effects_companies/miscellaneous_companies&ref_=pro_tt_pub_comp_add
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Froasted-beets%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2019%2F12%2Froasted-beets-pin.jpg&description=&is_video=false
# https://www.facebook.com/help/203805466323736?ref=dp
# https://contribute.imdb.com/updates/history?ref_=tt_pub_ftr_subm
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fcashew-cream%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2019%2F12%2Fcashew-cream-pin.jpg&description=&is_video=false
# https://www.facebook.com/help/contact/540977946302970
# https://contribute.imdb.com/updates/history?ref_=co_pub_ftr_subm
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Falmond-butter-recipe%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F05%2Falmond-butter-pin.jpg&description=&is_video=false
# https://www.facebook.com/help?ref=about.fb.com
# https://contribute.imdb.com/updates?edit=tt14857602&ref_=pro_tt_pub_edit
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fmimosa-recipe%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2020%2F03%2Fmimosas-pin.jpg&description=&is_video=false
# https://www.facebook.com/business/help?ref=about.fb.com
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Froasted-chickpeas%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F04%2Froasted-chickpeas-pin-1.jpg&description=&is_video=false
# https://www.facebook.com/creators/blog
# https://contribute.imdb.com/updates?update=tt9812474:production_companies/distributors/special_effects_companies/miscellaneous_companies&ref_=pro_tt_pub_comp_add
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fcornbread-recipe%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F04%2Fcornbread-recipe-pin-1.jpg&description=&is_video=false
# https://www.facebook.com/journalismproject
# https://www.loveandlemons.com/granola/comment-page-1/#comments
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Flabneh-recipe%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F04%2Flabneh-pin-1.jpg&description=&is_video=false
# https://www.facebook.com/help/work?ref=about.fb.com
# https://contribute.imdb.com/updates?update=tt4244994:inproduction&ref_=pro_tt_pub_edit_status
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fhealthy-banana-bread-recipe%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2019%2F03%2Fbanana-bread-pin-1.jpg&description=&is_video=false
# https://www.facebook.com/fbgaminghome/creators
# https://contribute.imdb.com/updates?edit=tt4244994&ref_=pro_tt_pub_edit
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Ffarro%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F04%2Ffarro-pin-1.jpg&description=&is_video=false
# https://www.facebook.com/fbgaminghome/developers
# https://contribute.imdb.com/dataset?ref_=helpms_ih_gi_siteindex
# https://www.loveandlemons.com/dinner-rolls-recipe/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fherb-compound-butter%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F08%2Fherb-compound-butter.jpg&description=&is_video=false
# https://www.facebook.com/careers/
# https://www.loveandlemons.com/no-knead-bread-recipe/
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fbroccoli-salad%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F04%2Fbroccoli-salad-pin-1.jpg&description=&is_video=false
# https://www.facebook.com/audiencenetwork
# https://contribute.imdb.com/updates?edit=co0049592/filmography&ref_=pro_co_pub_filmo_edit
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fsalad-recipes%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2021%2F04%2Fsalad-pin-1.jpg&description=&is_video=false
# https://contribute.imdb.com/updates?update=co0002663:branch.add.1&ref_=pro_co_pub_bo_add
# https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Fzucchini-noodles%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2019%2F08%2FIMG_20404.jpg&description=&is_video=false
# ...
# https://amzn.to/2Z6Mq5h
# https://www.loveandlemons.com/buddha-bowl-recipe/
# https://pro.imdb.com/name/nm1985859/?ref_=tt_pub_cst_img_2
# https://pro.imdb.com/title/tt7280898/?ref_=tt_pub_cst_kf_4
# https://www.loveandlemons.com/guacamole-recipe/
# https://pro.imdb.com/name/nm0455688/?ref_=tt_pub_cst_img_5
# https://pro.imdb.com/name/nm10068364/?ref_=tt_pub_cst_img_11
# https://pro.imdb.com/name/nm9691668/?ref_=tt_pub_cst_15
# https://pro.imdb.com/name/nm4215817/?ref_=tt_pub_cst_20
# https://advertising.amazon.com/resources/ad-policy/sponsored-display-policies?ref_=a20m_us_spcs_sdcap
# https://pro.imdb.com/discover/title?type=movie&status=post_production&ref_=co_pub_nv_tt_post
# https://advertising.amazon.com/resources/ad-specs/imdb/premium-takeover?ref_=a20m_us_spcs_prmblbr_prmtkv
# https://www.loveandlemons.com/cilantro-lime-rice/
# https://advertising.amazon.com/resources/ad-specs/mobile-shopping/?ref_=a20m_us_spcs_mbs
# https://www.loveandlemons.com/pumpkin-muffins/
# https://advertising.amazon.com/resources/ad-policy/creative-acceptance?ref_=a20m_us_spcs_cap
# https://www.amazon.jobs/cookies
# https://pro.imdb.com/title/tt4841570/?ref_=co_pub_filmo_projindev_2
# https://about.instagram.com/ko-kr/blog/
# https://pro.imdb.com/title/tt4199950/?ref_=co_pub_filmo_projindev_3
# https://advertising.amazon.com/resources/ad-specs/landing-pages/tailored/?ref_=a20m_us_spcs_talp
# https://pro.imdb.com/title/tt11143530/?ref_=co_pub_filmo
# https://about.instagram.com/blog/announcements/giving-young-people-a-safer-more-private-experience
# https://www.facebook.com/privacy/explanation
# https://ar-ar.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FBoxOfficeMojo%2F
# https://www.amazon.com/gp/help/customer/display.html?nodeId=201145440
# https://www.loveandlemons.com/jalapeno-cornbread
# https://www.facebook.com/ad_campaign/landing.php?campaign_id=163681540489385&creative&placement=%2Fbusiness%2Fmarketing%2Fmessenger&url=https%3A%2F%2Fwww.facebook.com%2Fbusiness%2Fhelp%2Fredirect%2F
# https://pl-pl.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FCedarsFoods%2F%3Ffref%3Dts
# https://www.loveandlemons.com/romesco-sauce/
# https://www.facebook.com/about/privacy
# https://advertising.amazon.com/resources/ad-specs/landing-pages?ref_=a20m_us_spcs_clp#custom-landing-pages
# https://www.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FBoxOfficeMojo%2F
# https://amzn.to/2O2Ct48
# https://www.facebook.com/recover/initiate?lwv=110&ars=royal_blue_bar
# https://pl-pl.facebook.com/login/identify/?ctx=recover&from_login_screen=0
# https://ar-ar.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FCedarsFoods%2F%3Ffref%3Dts
# https://de-de.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fads%2Fcreate
# https://www.facebook.com/about/privacy/update/printable
# https://help.imdb.com/article/imdb/general-information/i-used-a-third-party-linked-account-to-sign-up-and-no-longer-have-access-to-the-account-how-do-i-access-my-imdb-account/GS2JJYA7M2NGT977?ref_=helpart_nav_15
# https://www.facebook.com/ads/preferences/
# https://www.amazon.jobs/disability/us
# https://about.facebook.com/technologies/facebook-app/
# https://help.imdb.com/article/imdb/discover-watch/how-can-i-watch-a-movie-or-tv-show/G4GAAPL3XS2E99KY?ref_=helpart_nav_1
# https://www.facebook.com/help/353111348061173?ref=dp
# https://ro-ro.facebook.com/business/marketing/messenger
# https://www.facebook.com/help/1434403039959381?ref=dp
# https://help.imdb.com/article/imdb/discover-watch/movies-that-changed-my-life-an-imdb-podcast/GH3CCQKKXSJVGYD9?ref_=helpart_nav_4
# https://www.amazon.jobs
# https://www.loveandlemons.com/pasta-salad/
# https://www.facebook.com/ads/preferences
# https://help.imdb.com/article/imdb/discover-watch/collaborations-and-overlaps-search/G8P8WV3EHBDA4JJU?ref_=helpart_nav_14
# https://amzn.to/33QxZkP
# https://www.loveandlemons.com/egg-salad/
# https://help.imdb.com/article/imdb/discover-watch/i-m-looking-for-a-film-but-can-t-remember-the-title-can-you-help-me/GU8772QTK9U9PBMS?ref_=helpart_nav_19
# https://ro-ro.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fads%2Fcreate
# https://ar-ar.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdb
# https://www.loveandlemons.com/orzo-salad/
# https://www.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdbpro
# https://help.imdb.com/article/imdb/discover-watch/why-is-the-same-title-listed-twice-on-imdb/GR33YXUEDU3EP53Y?ref_=helpart_nav_25
# https://ro-ro.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FCedarsFoods%2F%3Ffref%3Dts
# https://www.facebook.com/help/publisher?ref=about.fb.com
# https://help.imdb.com/article/imdb/discover-watch/i-live-in-the-us-can-i-order-a-video-from-amazon-uk/G6U7CCAHCXQCVSNE?ref_=helpart_nav_36
# https://www.facebook.com/business
# https://www.loveandlemons.com/how-to-make-oatmeal/
# https://www.facebook.com/fbgaminghome/blog
# https://pl-pl.facebook.com/policy.php/
# https://www.loveandlemons.com/how-to-make-almond-milk/
# https://es-la.facebook.com/policy.php/
# https://about.facebook.com/technologies/messenger/
# https://www.loveandlemons.com/black-bean-soup-recipe/
# https://help.instagram.com/811572406418223?helpref=faq_content
# https://www.facebook.com/groups/130032510956456/
# https://about.facebook.com/technologies/instagram/
# https://www.amazon.com/gp/help/customer/display.html?nodeId=201909140
# https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fabout.fb.com%2Fnews%2F2021%2F08%2Fasking-people-for-their-birthday-on-instagram%2F&src=sdkpreparse
# https://help.instagram.com/477434105621119
# https://www.facebook.com/communitystandards/
# https://www.amazon.com/gp/video/detail/B097QHD7VJ/IMDBTV_ACQ_CRO_OTH_MLP_05G
# https://about.facebook.com/technologies/portal/
# https://www.facebook.com/terms.php
# https://facebook.com/business/help/582645198813984?helpref=page_content
# https://www.amazon.com/gp/yourstore/iyr/
# https://de-de.facebook.com/policy.php/
# https://play.google.com/store/books/category/audiobooks
# https://www.facebook.com/login/identify/?ctx=recover&from_login_screen=0
# https://ar-ar.facebook.com/payments_terms
# https://fo-fo.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FInsideAmazon%2F%3FAmazon.jobs%3Dfooter
# https://play.google.com/store
# https://about.facebook.com/technologies/oculus/
# https://help.instagram.com/502981923235522?helpref=page_content
# https://www.loveandlemons.com/pesto-recipe/
# https://www.facebook.com/legal/platformtobusinessnotice
# https://www.amazon.com/gp/video/splash/imdbtv_devicelinking
# https://about.facebook.com/actions/preparing-for-elections-on-facebook/
# https://www.loveandlemons.com/how-to-make-soft-boiled-eggs/
# https://about.facebook.com/company-info/
# https://help.instagram.com/?helpref=faq_content
# https://www.facebook.com/help/publisher
# https://www.amazon.com/Timewasters-Season-1-Trailer/dp/B095V21JCH/ref=IMDBTV_ACQ_CRO_OTH_MLP_05E
# https://es-la.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fseedandmill
# https://fr-fr.facebook.com/login/identify/?ctx=recover&from_login_screen=0
# https://play.google.com/store/apps/details?id=com.google.android.apps.docs.editors.slides&hl=en
# https://en.instagram-brand.com/
# https://www.facebook.com/audiencenetwork/products
# https://es-la.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FCedarsFoods%2F%3Ffref%3Dts
# https://help.instagram.com/?ref=ig_about
# https://fo-fo.facebook.com/watch/
# https://business.instagram.com/partnerships/
# https://www.facebook.com/safety/bullying
# https://www.loveandlemons.com/fruit-salad-recipe/
# https://fr-fr.facebook.com/business/marketing/messenger
# https://www.loveandlemons.com/caprese-sandwich/
# https://ar-ar.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FAmazonAds%2F
# https://de-de.facebook.com/help/568137493302217
# https://www.loveandlemons.com/chickpea-salad-sandwich/
# https://ar-ar.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fads%2Fcreate
# https://de-de.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FAmazonAds%2F
# https://business.instagram.com/success/?case_study_tags%5B0%5D=non-profits-and-organizations
# https://www.loveandlemons.com/vegan-quesadilla-recipe/
# https://help.instagram.com/519522125107875?helpref=faq_content
# https://fo-fo.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdb
# https://www.facebook.com/payments_terms/licenses
# https://policies.google.com/privacy?hl=da&utm_source=ucb
# https://www.nytimes.com/2021/09/20/nyregion/covid-vaccine-schools-nyc.html
# https://www.youtube.com/watch?v=iCFM9bRcvm4
# https://tr-tr.messenger.com/
# https://www.loveandlemons.com/porridge/
# https://policies.google.com/technologies/cookies?hl=da&utm_source=ucb
# https://www.nytimes.com/interactive/2021/us/cdc-mask-guidance-states.html
# https://de-de.facebook.com/business/marketing/messenger
# https://www.loveandlemons.com/nachos-recipe/
# https://www.facebook.com/policies_center#more-policy-types
# https://de-de.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FInsideAmazon%2F%3FAmazon.jobs%3Dfooter
# https://www.loveandlemons.com/mango-salsa/
# https://www.facebook.com/about/basics
# https://www.facebook.com/help/119468292028768?ref=dp
# https://de-de.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdb
# https://fr-fr.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FAmazonAds%2F
# https://www.loveandlemons.com/white-bean-dip/
# https://www.facebook.com/help/120939471321735?ref=dp
# https://de-de.facebook.com/watch/
# https://business.instagram.com/?ref=fb4b_site
# https://www.loveandlemons.com/spring-rolls/
# https://fr-fr.facebook.com/payments_terms/privacy
# https://www.oculus.com/lynx/?u=https%3A%2F%2Fwww.facebook.com%2Fcareers%2Fareas-of-work%2Foculus%2F&e=AT03T_iZfDKkj1cmWkh44YmnBLmSdlyUo-9CZRzUYIndiFyhuyirC-24-Y2zV8wI7Iiy3-AJrql24OFXFAcrpbQzOqWfIEBwL5R8ZQlrEI3TQ5nfqWRd6qP6ssKMtqPbF_NYSqwEkvIl1eCa
# https://www.loveandlemons.com/sauteed-mushrooms/
# https://www.facebook.com/help/contact/259518714718624
# https://de-de.facebook.com/business/learn/courses/instagram?ref=igb
# https://www.loveandlemons.com/grilled-ratatouille-tartines/
# https://www.facebook.com/help/contact/2061665240770586
# https://www.oculus.com/rift/
# https://www.loveandlemons.com/pickled-red-onions/
# https://da-dk.facebook.com/business/marketing/messenger
# https://accounts.google.com/TOS?loc=DK&hl=da
# https://about.facebook.com/technologies/workplace/
# https://da-dk.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdbpro
# https://accounts.google.com/ServiceLogin?hl=da&continue=https://www.youtube.com/channel/UC_vz6SvmIkYs1_H3Wv2SKlg?ref_%3Dhelpms_ih_dw_imdbvideos&gae=cb-23983171
# https://about.facebook.com/actions/protecting-privacy-and-security/
# https://play.google.com/store/apps/category/GAME
# https://about.facebook.com/media-gallery/
# https://play.google.com/movies
# https://www.nytimes.com/2021/09/20/us/texas-abortion-lawsuit-alan-braid.html
# https://www.youtube.com/watch?v=dCwHKlYQRBM
# https://pro-labs.imdb.com/cancel?ref_=helpms_ih_gi_deleteacct
# https://www.loveandlemons.com/tart-cherry-tabbouleh/
# https://help.instagram.com/2387676754836493
# https://www.loveandlemons.com/spinach-artichoke-dip/
# https://help.instagram.com
# https://play.google.com/store/movies/stream/promotion_collections_movie_studios
# https://www.facebook.com/help/151024075021791?ref=about.fb.com
# https://help.instagram.com/615366948510230
# https://play.google.com/store/paymentmethods
# https://www.nytimes.com/2021/09/20/travel/lost-tribe-jews-india-myanmar.html
# https://www.youtube.com/?gl=DK&tab=u1
# https://fo-fo.messenger.com/
# https://play.google.com/store/account/subscriptions
# https://www.nytimes.com/2021/09/17/opinion/ezra-klein-podcast-adam-tooze.html
# https://portal.facebook.com/help?ref=about.fb.com
# https://www.facebook.com/gpa/
# https://about.facebook.com/technologies/whatsapp/
# https://play.google.com/store/apps/details?id=com.imdb.mobile
# https://www.ez.insure/landing/press-release/
# https://help.instagram.com/105448789880240
# https://about.facebook.com/actions/promoting-safety-and-expression/
# https://help.instagram.com/537518769659039?helpref=page_content
# https://www.facebook.com/login.php?next=https%3A%2F%2Fwww.facebook.com%2Fads%2Fcreate
# https://help.instagram.com/559808137514535?helpref=page_content
# https://www.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fseedandmill
# https://play.google.com/store/apps/details?id=com.google.android.apps.fitness&hl=en
# https://policies.google.com/technologies/cookies
# https://www.loveandlemons.com/brussel-sprouts/
# https://about.facebook.com/news/2020/10/oculus-quest-2-is-now-available/
# https://help.instagram.com/519522125107875
# https://play.google.com/store/apps/details?id=com.google.android.apps.docs.editors.sheets&referrer=utm_source%3Dsheets_mkt%26utm_medium%3Dmobile_section%26utm_campaign%3Dsheets_mkt
# https://www.nytimes.com/2021/05/05/parenting/influencers-social-media-relationships.html
# https://accounts.google.com/AccountChooser?continue=https%3A%2F%2Fdrive.google.com%2F&emr=1&followup=https%3A%2F%2Fdrive.google.com%2F&service=wise
# https://itunes.apple.com/us/app/google-slides/id879478102?mt=8
# https://about.facebook.com/technologies/novi/
# https://developers.facebook.com/products/messenger/
# https://www.facebook.com/legal/music_guidelines
# https://da-dk.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdb
# https://accounts.google.com/ServiceLogin?hl=da&cd=DK&continue=https://translate.google.dk/?hl%3Dda&gae=cb-
# https://itunes.apple.com/app/arts-culture/id1050970557?pt=9008&ct=stella-home&mt=8
# https://www.facebook.com/policy/
# https://da-dk.facebook.com/login/identify/?ctx=recover&ars=facebook_login&from_login_screen=0
# https://accounts.google.com/signin/usernamerecovery?continue=https%3A%2F%2Fpolicies.google.com%2Fterms%3Fhl%3Dda%26utm_source%3Ducb&hl=da
# https://itunes.apple.com/us/app/apple-store/id375380948?mt=8
# https://accounts.google.com/ServiceLogin?service=accountsettings&continue=https://myaccount.google.com%3Futm_source%3Daccount-marketing-page%26utm_medium%3Dgo-to-account-button
# https://itunes.apple.com/app/apple-store/id842849113?pt=9008&ct=sheets_mkt&mt=8
# https://consent.youtube.com/dl?continue=https://www.youtube.com/channel/UCUqWkv7uVXxqIlPHbTY2ctw&gl=DK&hl=da&pc=yt&uxe=23983171&src=1
# https://www.oculus.com/research/
# https://da-dk.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FBoxOfficeMojo%2F
# https://accounts.google.com/signup
# https://www.loveandlemons.com/shakshuka/
# https://www.facebook.com/business/help/261457568615847
# https://www.loveandlemons.com/stuffed-zucchini-boats/
# https://www.nytimes.com/privacy/cookie-policy#how-do-i-manage-trackers
# https://www.facebook.com/facebookpaysupport
# https://www.youtube.com/facebook/
# https://blog.aboutamazon.com/?utm_source=gateway&utm_medium=footer&token=about
# https://www.loveandlemons.com/vegan-tacos/
# https://about.facebook.com/actions/responding-to-covid-19/
# https://help.instagram.com/488619974671134
# https://www.loveandlemons.com/tomato-soup/
# https://about.facebook.com/reality-labs/ray-ban-stories/privacy
# https://www.loveandlemons.com/grilled-vegetables/
# https://www.facebook.com/payments_terms/privacy.php
# https://www.oculus.com/legal/privacy-policy/
# https://www.loveandlemons.com/peanut-sauce/
# https://www.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FInsideAmazon%2F%3FAmazon.jobs%3Dfooter
# https://help.instagram.com/2922067214679225
# https://www.loveandlemons.com/pico-de-gallo/
# https://www.facebook.com/settings
# https://help.instagram.com/535503073130320?helpref=faq_content
# https://www.loveandlemons.com/buddha-bowl-turmeric-tahini-sauce/
# https://www.oculus.com/blog/workrooms/
# https://www.loveandlemons.com/roasted-vegetable-pasta/
# https://www.facebook.com/help/494750870625830?ref=dp
# https://www.nytimes.com/interactive/2021/us/covid-cases.html
# https://www.youtube.com/watch?v=Nv2GmUtCbVQ
# https://help.instagram.com/140491076362332
# https://play.google.com/intl/da_us/about/play-terms.html
# https://da-dk.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2FAmazonAds%2F
# https://accounts.google.com/ServiceLogin?hl=da&continue=https://www.youtube.com/amazonadvertising/&gae=cb-23983171
