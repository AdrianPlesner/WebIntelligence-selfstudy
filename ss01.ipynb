# %% [markdown]
# # Self study 1
#
# Self studies should be solved individually, or in small groups of 2-3 students. There is no hand-in of your solutins to the self studies. However, you can bring your solutions to the exam, and use them as the basis for your answers to the exam questions.
#
# In this self-study we construct a simple crawler. Concretely, you should:
#
# * Select about 5 seed urls, e.g. homepages of universities, e-commerce sites, or similar
#
# * Start crawling from these seeds. Define a strategy for selecting the next url to be crawled. What kind of prioritization (if any) is embodied in your strategy?
#
# * Make sure you obey the robots.txt file, and make ensure that at least 2 seconds elapse between requests to the same host
#
# * Stop when you have crawled approx. 1000 pages
#
# * For each crawled page, save the url and the text string contained in the 'title' element of the document (we do not want to handle the full text of the pages at this point).
#
# * You can repeat this several times, using different seed sets and/or prioritization strategies.
#
# The following two self studies will extend the work that you do in this self study.

# %% [markdown]
# The following introduces a few helpful libraries and essential functions. You can use these methods, or use other tools that you are already familiar with and/or prefer to work with.
#
# A simple crawler implementation can be based on the 'requests' package [https://requests.readthedocs.io/en/master/](https://requests.readthedocs.io/en/master/) for retrieving html documents, and the BeautifulSoup parser https://www.crummy.com/software/BeautifulSoup/bs4/doc/ for parsing the html.

# %%
import requests
from bs4 import BeautifulSoup
from time import sleep
from urllib.robotparser import RobotFileParser

# %% [markdown]
# Let's start crawling at https://www.aau.dk/ . We first retrieve the robots.txt file and check whether we are allowed to crawl the top-level url:

# %%
rp=RobotFileParser()
rp.set_url("https://www.aau.dk/")
rp.read()
print(rp.can_fetch("*","https://www.aau.dk"))
# Out:
# True

# %% [markdown]
# We can now get the html using the requests package, which returns a response object:

# %%
r=requests.get('https://www.aau.dk/')
print(type(r))
# Out:
# <class 'requests.models.Response'>

# %% [markdown]
# A basic view of the contents is accessible via the content attribute:

# %%
r.content
# Out:
# b'<!DOCTYPE html>\r\n<html class="no-js" prefix="og: http://ogp.me/ns#">\r\n<head>\r\n<meta charset="utf-8" />\r\n<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1">\r\n\r\n\r\n<meta name="description" content="Aalborg Universitet - Problem- og projektbaseret forskning og uddannelse, der i samspil mellem AAU og omverdenen skaber viden, der forandrer verden." />\r\n<title>AAU - Viden for verden</title>\r\n\r\n<!-- Cookie Information Consent -->\r\n<script id="CookieConsent" src="https://policy.app.cookieinformation.com/uc.js" data-culture="DA" type="text/javascript"></script>\r\n<!-- Remove no-js enable html5 elements -->\r\n<script type="text/javascript">\r\n    //Clear no-js\r\n    document.getElementsByTagName(\'html\')[0].className = document\r\n            .getElementsByTagName(\'html\')[0].className.replace(\'no-js\', \'\');\r\n    //Enable html5 elements in IE\r\n    \'article aside footer header nav section time\'.replace(/\\w+/g, function(n) {\r\n        document.createElement(n)\r\n    });\r\n</script>\r\n\r\n<!-- Google Tag Manager --> <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\': new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src= \'//www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f); })(window,document,\'script\',\'dataLayer\',\'GTM-K2LH48\');</script> <!-- End Google Tag Manager --><meta name="twitter:card" content="summary" />\r\n\r\n<script type="text/javascript" src="https://fast.fonts.com/jsapi/6ffba2ea-d55c-4389-b794-a04d376df85c.js"></script>\r\n\r\n<link rel="stylesheet" type="text/css" href="https://www.resources.aau.dk/design2013/resources/css/style.min.css" />\r\n\r\n<link rel="stylesheet" type="text/css"\r\n        href="https://www.design2013.aau.dk/backgroundCss?image=%2FdigitalAssets%2F386%2F386754_858170_393929_393929_aaudk_makeitreal5.jpg" />\r\n<link rel="shortcut icon" type="image/vnd.microsoft.ico" href="https://www.resources.aau.dk/design2013/images/aaufavicon.ico?v=2" />\r\n<link rel="alternate" type="application/rss+xml" href="https://www.aau.dk/?rss=23" /><link rel="alternate" type="application/rss+xml" href="https://www.aau.dk/?rss=24" />\n</head>\r\n\r\n<!--[if lt IE 7]> <body class="ie6"> <![endif]--><!--[if IE 7]><body class="ie7"><![endif]--><!--[if IE 8]><body class="ie8"> <![endif]--><!--[if gt IE 8]><!--><body>\r\n\t<!-- Google Tag Manager --> <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-K2LH48" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><!-- End Google Tag Manager --><!--<![endif]--><div class="bg-img"></div>\r\n\r\n    <!-- StickyFooter --><div class="stickyFooter">    \r\n        <!-- Service menu --><div id="servicemenu" class="wrapper cf"> \n <div class="servicemenuInner box white"> \n  <input type="hidden" value="false" id="useOverlay"> \n  <nav> \n   <div class="shortCutsWrapper"> \n    <button class="navbar__toggler hamburger--spin collapsed" id="shortcuthamburger" type="button" data-toggle="collapse" data-target="#shortcutsMeny" data-parent="" aria-expanded="false"> \n     <div class="hamburger__inner"> \n      <span class="hamburger__icon"></span> \n     </div> </button> \n    <ul class="shortCutDropdown unstyled" id="shortcutsMeny"> \n     <li> <style>    .topLink white .link:hover{    color: ;  }</style><a href="https://www.aau.dk/nyheder" title="Nyheder fra AAU" class="topLink white">Nyheder</a></li> \n     <li> <style>    .topLink white .link:hover{    color: ;  }</style><a href="https://www.aau.dk/arrangementer" title="Arrangementer p\xc3\xa5 AAU" class="topLink white">Arrangementer</a></li> \n     <li> <style>    .topLink white .link:hover{    color: ;  }</style><a href="https://www.aau.dk/kontakt" title="Kontakt og find rundt p\xc3\xa5 Aalborg Universitet" class="topLink white">Kontakt og find rundt</a></li> \n     <li> <style>    .t ...

# %% [markdown]
# For serious parsing, we can use the BeautifulSoup html parser:

# %%
r_parse = BeautifulSoup(r.text, 'html.parser')
print(r_parse.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="Aalborg Universitet - Problem- og projektbaseret forskning og uddannelse, der i samspil mellem AAU og omverdenen skaber viden, der forandrer verden." name="description">
#    <title>
#     AAU - Viden for verden
#    </title>
#    <!-- Cookie Information Consent -->
#    <script data-culture="DA" id="CookieConsent" src="https://policy.app.cookieinformation.com/uc.js" type="text/javascript">
#    </script>
#    <!-- Remove no-js enable html5 elements -->
#    <script type="text/javascript">
#     //Clear no-js
#     document.getElementsByTagName('html')[0].className = document
#             .getElementsByTagName('html')[0].className.replace('no-js', '');
#     //Enable html5 elements in IE
#     'article aside footer header nav section time'.replace(/\w+/g, function(n) {
#         document.createElement(n)
#     });
#    </script>
#    <!-- Google Tag Manager -->
#    <script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-K2LH48');
#    </script>
#    <!-- End Google Tag Manager -->
#    <meta content="summary" name="twitter:card"/>
#    <script src="https://fast.fonts.com/jsapi/6ffba2ea-d55c-4389-b794-a04d376df85c.js" type="text/javascript">
#    </script>
#    <link href="https://www.resources.aau.dk/design2013/resources/css/style.min.css" rel="stylesheet" type="text/css"/>
#    <link href="https://www.design2013.aau.dk/backgroundCss?image=%2FdigitalAssets%2F386%2F386754_858170_393929_393929_aaudk_makeitreal5.jpg" rel="stylesheet" type="text/css"/>
#    <link href="https://www.resources.aau.dk/design2013/images/aaufavicon.ico?v=2" rel="shortcut icon" type="image/vnd.microsoft.ico"/>
#    <link href="https://www.aau.dk/?rss=23" rel="alternate" type="application/rss+xml"/>
#    <link href="https://www.aau.dk/?rss=24" rel="alternate" type="application/rss+xml"/>
#   </meta>
#  </head>
#  <!--[if lt IE 7]> <body class="ie6"> <![endif]-->
#  <!--[if IE 7]><body class="ie7"><![endif]-->
#  <!--[if IE 8]><body class="ie8"> <![endif]-->
#  <!--[if gt IE 8]><!-->
#  <body>
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-K2LH48" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager -->
#   <!--<![endif]-->
#   <div class="bg-img">
#   </div>
#   <!-- StickyFooter -->
#   <div class="stickyFooter">
#    <!-- Service menu -->
#    <div class="wrapper cf" id="servicemenu">
#     <div class="servicemenuInner box white">
#      <input id="useOverlay" type="hidden" value="false"/>
#      <nav>
#       <div class="shortCutsWrapper">
#        <button aria-expanded="false" class="navbar__toggler hamburger--spin collapsed" data-parent="" data-target="#shortcutsMeny" data-toggle="collapse" id="shortcuthamburger" type="button">
#         <div class="hamburger__inner">
#          <span class="hamburger__icon">
#          </span>
#         </div>
#        </button>
#        <ul class="shortCutDropdown unstyled" id="shortcutsMeny">
#         <li>
#          <style>
#           .topLink white .link:hover{    color: ;  }
#          </style>
#          <a class="topLink white" href="https://www.aau.dk/nyheder" title="Nyheder fra AAU">
#           Nyheder
#          </a>
#         </li>
#         <li>
#          <style>
#           .topLink white .link:hover{    color: ;  }
#          </style>
#          <a class="topLink white" href="https://www.aau.dk/arrangementer" title="Arrangementer på AAU">
#           Arrangementer
#          </a>
#         </li>
#         <li>
#          <style>
#           .topLink white .link:hover{    color: ;  }
#          </style>
#          <a class="topLink white" href="https://www.aau.dk/kontakt" title="Kontakt og find rundt på Aalborg Universitet">
#           Kontakt og find rundt
#          </a>
#         </li>
#         <li>
#          <style>
#           .topLink white .link:hover{    color: ;  }
#          </style>
#          <a class="topLink white" href="https://www.aau.dk/om-aau/organisation/campus" title="Campusområder på AAU">
#           Campusområder
#          </a>
#         </li>
#         <li>
#          <style>
#           .topLink white .link:hover{    color: ;  }
#          </style>
#          <a class="topLink white" href="https://www.aau.dk/pressen" title="For pressen">
#           For Pressen
#          </a>
#         </li>
#         <li>
#          <style>
#           .topLink white .link:hover{    color: ;  }
#          </style>
#          <a class="topLink white" href="https://www.alumni.aau.dk/" title="For alumni">
#           For alumni
#          </a>
#         </li>
#        </ul>
#       </div>
#       <!-- Mobile hamburger -->
#       <button aria-expanded="false" class="navbar__toggler hamburger--spin collapsed navbar__toggler--mobile" data-parent="" data-target="#mobileMenu" data-toggle="collapse" type="button">
#        <div class="hamburger__inner">
#         <span class="hamburger__icon">
#         </span>
#        </div>
#       </button>
#       <ul class="horizontal unstyled flexnavigation" id="mobileMenu">
#        <!-- Mobile menu shortcuts -->
#        <li class="serviceMenuCenterItem shortCutDropdownMenu">
#         <a class="topLink shortcutExpandLink" href="#">
#          Genveje
#         </a>
#         <ul class="shortCutDropdown unstyled shortcutsmobile">
#          <li>
#           <style>
#            .topLink white .link:hover{    color: ;  }
#           </style>
#           <a class="topLink white" href="https://www.aau.dk/nyheder" title="Nyheder fra AAU">
#            Nyheder
#           </a>
#          </li>
#          <li>
#           <style>
#            .topLink white .link:hover{    color: ;  }
#           </style>
#           <a class="topLink white" href="https://www.aau.dk/arrangementer" title="Arrangementer på AAU">
#            Arrangementer
#           </a>
#          </li>
#          <li>
#           <style>
#            .topLink white .link:hover{    color: ;  }
#           </style>
#           <a class="topLink white" href="https://www.aau.dk/kontakt" title="Kontakt og find rundt på Aalborg Universitet">
#            Kontakt og find rundt
#           </a>
#          </li>
#          <li>
#           <style>
#            .topLink white .link:hover{    color: ;  }
#           </style>
#           <a class="topLink white" href="https://www.aau.dk/om-aau/organisation/campus" title="Campusområder på AAU">
#            Campusområder
#           </a>
#          </li>
#          <li>
#           <style>
#            .topLink white .link:hover{    color: ;  }
#           </style>
#           <a class="topLink white" href="https://www.aau.dk/pressen" title="For pressen">
#            For Pressen
#           </a>
#          </li>
#          <li>
#           <style>
#            .topLink white .link:hover{    color: ;  }
#           </style>
#           <a class="topLink white" href="https://www.alumni.aau.dk/" title="For alumni">
#            For alumni
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="serviceMenuCenterItem">
#         <style>
#          .topLink .link:hover{    color: ;  }
#         </style>
#         <a class="topLink" href="https://www.aau.dk/uddannelser/">
#          aau uddannelse
#         </a>
#        </li>
#        <li class="serviceMenuCenterItem">
#         <style>
#          .topLink .link:hover{    color: ;  }
#         </style>
#         <a class="topLink" href="https://www.aau.dk/forskning/">
#          aau forskning
#         </a>
#        </li>
#        <li class="serviceMenuCenterItem">
#         <style>
#          .topLink .link:hover{    color: ;  }
#         </style>
#         <a class="topLink" href="https://www.aau.dk/samarbejde/">
#          aau samarbejde
#         </a>
#        </li>
#        <li class="serviceMenuCenterItem">
#         <style>
#          .topLink .link:hover{    color: ;  }
#         </style>
#         <a class="topLink" href="https://www.aau.dk/om-aau/">
#          Om AAU
#         </a>
#        </li>
#        <li class="serviceMenuCenterItem">
#         <style>
#          .topLink .link:hover{    color: ;  }
#         </style>
#         <a class="topLink" href="https://www.stillinger.aau.dk/">
#          Ledige stillinger
#         </a>
#        </li>
#        <li class="serviceMenuCenterItem">
#         <style>
#          .topLink .link:hover{    color: ;  }
#         </style>
#         <a class="topLink" href="https://www.intern.aau.dk/">
#          Ansatte og studerende
#         </a>
#        </li>
#        <li class="serviceMenuCenterItem hiddenMobile">
#         <a class="topLink searchMenu" href="https://www.search.aau.dk/?locale=da" id="search_icon_link">
#          <span class="topLinkIcon search">
#          </span>
#         </a>
#        </li>
#        <li class="serviceMenuCenterItem hiddenMobile">
#         <a class="topLink" href="https://www.en.aau.dk/">
#          <span class="topLinkIcon english">
#          </span>
#         </a>
#        </li>
#       </ul>
#       <a class="topLinkMobile topLink searchMenu" href="https://www.search.aau.dk/?locale=da" id="search_icon_link_2">
#        <span class="topLinkIcon search">
#        </span>
#       </a>
#       <a class="topLinkMobile topLink topLinkMobileLanguage" href="https://www.en.aau.dk/">
#        <span class="topLinkIcon english">
#        </span>
#       </a>
#      </nav>
#     </div>
#     <!-- End service menu -->
#     <input id="languageCodeInput" type="hidden" value="en"/>
#     <div id="search-div">
#      <div id="close-search-div">
#      </div>
#      <iframe id="search-iframe" src="https://aau-search-web-prod.azurewebsites.net/">
#      </iframe>
#     </div>
#     <script type="text/javascript">
#      var width = window.outerWidth;		var mobile = true;		if(width > 768) {			mobile = false;		}		var iframe = document.getElementById("search-iframe");		var languageCode = document.getElementById("languageCodeInput").value;		if("" === languageCode || languageCode === undefined){			languageCode = "da";		}		var url = iframe.src;		var index = url.indexOf("?");		var urlParamsIframe;				if(index != -1){			urlParamsIframe = "&";		}else{			urlParamsIframe = "?";		}		var searchElement = document.getElementById("search_icon_link");		var searchElement2 = document.getElementById("search_icon_link_2");		var mobileUrl = searchElement.href;		var index2 = mobileUrl.indexOf("?");		var urlParamsMobile;		if(index2 != -1){			urlParamsMobile = "&";		}else{			urlParamsMobile = "?";		}		var params = "mobile=" + mobile + "&site="+window.location.hostname;		var languageParam = "&locale="+languageCode;		urlParamsIframe += params;		urlParamsMobile += params;				index = url.indexOf("locale");		if(index == -1){			urlParamsIframe += languageParam;		}		index2 = mobileUrl.indexOf("locale");				if(index2 == -1){			urlParamsMobile += languageParam;		}				var mobileUrlWithParams = mobileUrl + urlParamsMobile;		iframe.src = iframe.src + urlParamsIframe;					searchElement.href = mobileUrlWithParams;		searchElement2.href = mobileUrlWithParams;
#     </script>
#    </div>
#    <!-- End service menu -->
#    <!--  Marquee -->
#    <div class="wrapper">
#    </div>
#    <!--  end Marquee -->
#    <div id="top">
#     <div class="wrapper">
#      <div class="section">
#       <div class="spotCon grid g12 isCentered">
#        <a href="https://www.aau.dk">
#         <img alt="AAU logo" src="https://www.resources.aau.dk/design2013/images/logo.png"/>
#        </a>
#       </div>
#       <!--  MegaDropdown menu -->
#       <div class="spotCon grid g12">
#        <div class="megadropdown">
#         <div class="grid g4">
#          <a class="tab box white h2" href="#">
#           Uddannelse
#           <div class="subText navigationTitle">
#            Find din AAU-uddannelse
#           </div>
#          </a>
#          <div class="mega white">
#           <nav>
#            <div class="section">
#             <div class="spotCon grid g4">
#              <div class="box white teaser">
#               <a class="smallButton" href="https://www.aau.dk/uddannelser/">
#                <img alt="Uddannelse" src="/digitalAssets/64/64328_uddannelseweb.png"/>
#                <span class="h2">
#                 Gå til Uddannelser
#                </span>
#                <div class="navigationTitle">
#                 Læs om din AAU-uddannelse
#                </div>
#               </a>
#              </div>
#             </div>
#             <div class="spotCon grid g4">
#              <div class="box white" style="">
#               <span class="h2">
#                Uddannelser på AAU
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/bachelor" title="Bacheloruddannelser på Aalborg Universitet → Læs mere her.">
#                  <h3 class="hasArrow">
#                   bacheloruddannelser
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/kandidat" title="Kandidatuddannelser på Aalborg Universitet">
#                  <h3 class="hasArrow">
#                   Kandidatuddannelser
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/sidefag-tilvalgsfag" title="Sidefag og tilvalgsfag på Aalborg Universitet">
#                  <h3 class="hasArrow">
#                   Sidefag og tilvalgsfag
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/bliv-gymnasielaerer" title="Bliv gymnasielærer">
#                  <h3 class="hasArrow">
#                   Bliv gymnasielærer
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.evu.aau.dk" title="AAU's Efter- og videreuddannelse, Masterakademiet">
#                  <h3 class="hasArrow">
#                   Master- og efter- &amp; videreuddannelse
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="box white" style="">
#               <span class="h2">
#                optagelse
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/optagelse/bachelor" title="Optagelse på en Bachelor">
#                  <h3 class="hasArrow">
#                   Optagelse på en Bachelor
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="http://www.adgangstjekker.aau.dk" title="Tjek adgangskrav med AAU's Adgangstjekker">
#                  <h3 class="hasArrow">
#                   Tag et adgangstjek
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/optagelse/kandidat/" title="Optagelse på en Kandidat">
#                  <h3 class="hasArrow">
#                   Optagelse på en Kandidat
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/optagelse/indskrivning-gaestestuderende-studieskift" title="Indskrivning, merit og gæstestuderende">
#                  <h3 class="hasArrow">
#                   Indskrivning, merit og gæstestuderende
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/optagelse/adgangskursus" title="Adgangskursus og supplering">
#                  <h3 class="hasArrow">
#                   Adgangskursus og supplering
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/optagelse/Optagelsesvejledning/" title="Optagelsesvejledning">
#                  <h3 class="hasArrow">
#                   Optagelsesvejledning
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="box white" style="">
#               <span class="h2">
#                Mød Aalborg Universitet
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/moed-aau" title="Mød Aalborg Universitet">
#                  <h3 class="hasArrow">
#                   Mød universitetet
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="spotCon grid g4">
#              <div class="box white" style="">
#               <span class="h2">
#                Om at studere på AAU
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/gruppe-og-projektarbejde" title="Gruppe- og projektarbejde på AAU">
#                  <h3 class="hasArrow">
#                   Gruppe- og projektarbejde
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/her-kan-du-studere-paa-aau/aalborg" title="AAU i Aalborg">
#                  <h3 class="hasArrow">
#                   AAU i Aalborg
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/her-kan-du-studere-paa-aau/esbjerg" title="Aalborg Universitet i Esbjerg">
#                  <h3 class="hasArrow">
#                   AAU i Esbjerg
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/her-kan-du-studere-paa-aau/koebenhavn" title="Aalborg Universitet i København">
#                  <h3 class="hasArrow">
#                   AAU i København
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="box white" style="">
#               <span class="h2">
#                Studievejledning
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/optagelse/" title="Optagelsesvejledning (for kommende studerende, spørg om studievalg, ansøgning og optagelse)">
#                  <h3 class="hasArrow">
#                   Optagelsesvejledning (for kommende studerende, spørg om studievalg, ansøgning og optagelse)
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/studievejledning/" title="Studie- og trivselsvejledning (for indskrevne studerende, spørg om trivsel, orlov, studietvivl)">
#                  <h3 class="hasArrow">
#                   Studie- og trivselsvejledning (for indskrevne studerende, spørg om trivsel, orlov, studietvivl)
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/studievejledning/studiets-vejledere" title="Studiernes egne studievejledere (spørg om fagligt indhold, praktik, studiemiljø, eksamen)">
#                  <h3 class="hasArrow">
#                   Studiernes egne studievejledere (spørg om fagligt indhold, praktik, studiemiljø, eksamen)
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/su" title="Statens Uddannelsesstøtte (SU)">
#                  <h3 class="hasArrow">
#                   Statens Uddannelsesstøtte (SU)
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/uddannelser/sps" title="SPS Støttemuligheder (SPS) ">
#                  <h3 class="hasArrow">
#                   SPS Støttemuligheder (SPS)
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="clear cleargrid">
#             </div>
#            </div>
#           </nav>
#          </div>
#         </div>
#         <div class="grid g4">
#          <a class="tab box white h2" href="#">
#           Forskning
#           <div class="subText navigationTitle">
#            Find AAU-forskning og -forskere
#           </div>
#          </a>
#          <div class="mega white">
#           <nav>
#            <div class="section">
#             <div class="spotCon grid g4">
#              <div class="box white teaser">
#               <a class="smallButton" href="https://www.aau.dk/forskning/">
#                <img alt="Forskning" src="/digitalAssets/64/64330_forskningweb.png"/>
#                <span class="h2">
#                 Gå til Forskning
#                </span>
#                <div class="navigationTitle">
#                 Læs om AAU's forskning
#                </div>
#               </a>
#              </div>
#             </div>
#             <div class="spotCon grid g4">
#              <div class="box white" style="">
#               <span class="h2">
#                Find forskning fra AAU
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://vbn.aau.dk/da/publications/search.html" title="Find forskningspublikationer fra AAU">
#                  <h3 class="hasArrow">
#                   Publikationer
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://vbn.aau.dk/da/projects/search.html" title="Find forskningsprojekter fra AAU">
#                  <h3 class="hasArrow">
#                   Projekter
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://vbn.aau.dk/da/persons/search.html?current=true" title="Find forskere på AAU">
#                  <h3 class="hasArrow">
#                   Personer
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://vbn.aau.dk/da/clippings/" title="AAU's forskning i pressen">
#                  <h3 class="hasArrow">
#                   Forskning i pressen
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="box white" style="">
#               <span class="h2">
#                Forskningsenheder
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/forskning/forskningsenheder/institutter" title="Aalborg Universitets institutter">
#                  <h3 class="hasArrow">
#                   Institutter
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/forskning/phd/phd-skoler" title="Ph.d.-skoler på Aalborg Universitet">
#                  <h3 class="hasArrow">
#                   Ph.d.-skoler
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://vbn.aau.dk/da/organisations/?format=&amp;type=%2Fdk%2Fatira%2Fpure%2Forganisation%2Forganisationtypes%2Forganisation%2Fknowledgecenter&amp;nofollow=true" title="Find AAU's forskningscentre">
#                  <h3 class="hasArrow">
#                   Forskningscentre
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="spotCon grid g4">
#              <div class="box white" style="">
#               <span class="h2">
#                Om forskning
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://www.strategi.aau.dk/Forskning" title="Forskning">
#                  <h3 class="hasArrow">
#                   Forskning
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/forskning/open-access" title="Open Access">
#                  <h3 class="hasArrow">
#                   Open Access
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/forskning/ranking" title="Ranking på Aalborg Universitet">
#                  <h3 class="hasArrow">
#                   ranking
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.stillinger.aau.dk/videnskabelige-stillinger/" title="Forskerstillinger">
#                  <h3 class="hasArrow">
#                   Forskerstillinger
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="box white" style="">
#               <span class="h2">
#                Ph.D.
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/forskning/phd/" title="PH.D. på AAU">
#                  <h3 class="hasArrow">
#                   PH.D. på AAU
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/forskning/phd/phd-skoler/" title="PH.D. Skoler">
#                  <h3 class="hasArrow">
#                   PH.D. Skoler
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.stillinger.aau.dk/phd-stillinger/" title="Se ledige ph.d.-stillinger på AAU">
#                  <h3 class="hasArrow">
#                   Stillinger
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/forskning/phd/soeg-phd/" title="Søg en ph.d.-stilling på AAU">
#                  <h3 class="hasArrow">
#                   Ansøgning
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/virksomheder/samarbejde-forskere/erhvervsphd" title="Få en erhvervsPh.D-studerende">
#                  <h3 class="hasArrow">
#                   Få en erhvervsPh.D-studerende
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="clear cleargrid">
#             </div>
#            </div>
#           </nav>
#          </div>
#         </div>
#         <div class="grid g4">
#          <a class="tab box white h2" href="#">
#           Samarbejde
#           <div class="subText navigationTitle">
#            Samarbejd med AAU
#           </div>
#          </a>
#          <div class="mega white">
#           <nav>
#            <div class="section">
#             <div class="spotCon grid g4">
#              <div class="box white teaser">
#               <a class="smallButton" href="https://www.aau.dk/samarbejde/">
#                <img alt="Samarbejde" src="/digitalAssets/64/64329_samarbejdeweb.png"/>
#                <br/>
#                <span class="h2">
#                 Gå til Samarbejde
#                </span>
#                <div class="navigationTitle">
#                 Læs om hvordan du kan samarbejde med AAU
#                </div>
#               </a>
#              </div>
#             </div>
#             <div class="spotCon grid g4">
#              <div class="box white" style="">
#               <span class="h2">
#                Samarbejdstilbud til virksomheder og offentlige institutioner
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/guide-samarbejde" title="Din guide til samarbejde med AAU">
#                  <h3 class="hasArrow">
#                   Guide til samarbejde
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/virksomheder/efter-videreuddannelse" title="Bliv efter- og videreuddannet på Aalborg Universitet">
#                  <h3 class="hasArrow">
#                   Efteruddannelse
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/virksomheder/Erhvervsklynger" title="Deltag i Danmarks Erhvervsklynger">
#                  <h3 class="hasArrow">
#                   Deltag i Danmarks Erhvervsklynger
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/virksomheder/find-medarbejdere" title="Find din nye medarbejder">
#                  <h3 class="hasArrow">
#                   Find din nye medarbejder
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/virksomheder/profiler-virksomhed" title="Profilér din virksomhed over for AAU's studerende">
#                  <h3 class="hasArrow">
#                   Profilér din virksomhed
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/virksomheder/samarbejde-forskere" title="Samarbejd med forskere på Aalborg Universitet">
#                  <h3 class="hasArrow">
#                   Samarbejd med forskere
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/virksomheder/samarbejde-studerende" title="Samarbejd med studerende på Aalborg Universitet">
#                  <h3 class="hasArrow">
#                   Samarbejd med studerende
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/virksomheder/laboratorier-udstyr" title="Lej laboratorier og udstyr på Aalborg Universitet">
#                  <h3 class="hasArrow">
#                   Lej laboratorier og udstyr
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/virksomheder/udnyt-opfindelser" title="Vær med til at udnytte opfindelser og teknologi">
#                  <h3 class="hasArrow">
#                   Udnyt opfindelser &amp; teknologi
#                  </h3>
#                 </a>
#                </li>
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/myndigheder-sektorer" title="Samarbejde med myndigheder og sektorer">
#                  <h3 class="hasArrow">
#                   Samarbejde med myndigheder og sektorer
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="spotCon grid g4">
#              <div class="box white" style="">
#               <span class="h2">
#                Samarbejdstilbud til gymnasier
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://www.aau.dk/samarbejde/tilbud-til-gymnasier" title="AAU's tilbud til gymnasier">
#                  <h3 class="hasArrow">
#                   Tilbud til gymnasier
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="box white" style="">
#               <span class="h2">
#                Samarbejdstilbud for tidligere studerende
#               </span>
#               <style>
#                .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#               </style>
#               <ul class="unstyled">
#                <li>
#                 <a class="inlineBlock" href="https://www.alumni.aau.dk" title="AAU Alumni">
#                  <h3 class="hasArrow">
#                   AAU Alumni
#                  </h3>
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="clear cleargrid">
#             </div>
#            </div>
#           </nav>
#          </div>
#         </div>
#        </div>
#       </div>
#       <!--  End megaDropdown menu -->
#       <div class="clear cleargrid">
#       </div>
#      </div>
#      <!--  Localmenu -->
#      <!--  end Localmenu -->
#     </div>
#    </div>
#    <div class="overlay">
#    </div>
#    <!-- Main -->
#    <div id="main">
#     <!-- Wrapper in Main-->
#     <div class="wrapper">
#      <div class="section">
#       <div class="spotCon grid g12">
#        <h1 class="highlighted">
#         AAU - Viden for verden
#        </h1>
#       </div>
#       <div class="clear cleargrid">
#       </div>
#      </div>
#      <div class="section">
#       <div class="spotCon grid g12">
#       </div>
#       <div class="clear cleargrid">
#       </div>
#      </div>
#      <div class="section">
#       <div class="spotCon grid g8">
#        <div class="article" itemscope="" itemtype="http://schema.org/Article">
#         <div class="box white">
#          <a href="https://www.aau.dk/uddannelser">
#           <img alt="Studerende på AAU" itemprop="image" src="/digitalAssets/1111/1111690_aau-studerende.gif" title="Studerende på AAU">
#           </img>
#          </a>
#          <meta content="2022-01-03T07:49+0100" itemprop="dateModified"/>
#          <meta content="2022-01-03T07:31+0100" itemprop="datePublished"/>
#          <div itemprop="articleBody">
#           <p>
#            <a class="smallButton" href="https://www.aau.dk/uddannelser">
#             Bliv studerende på AAU
#            </a>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="spotCon grid g4">
#        <div class="box color" style="">
#         <style>
#          .link:hover {
# 		color: FFFFF;
# 	}
#
# 	.color .link:hover{
# 		color: FFFFF;
# 	}
#         </style>
#         <ul class="unstyled">
#          <li>
#           <a class="inlineBlock link" href="/coronavirus/" title="coronavirus">
#            <h3 class="hasArrow">
#             Information om coronavirus
#            </h3>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="box white" style="">
#         <span class="h2">
#          UDDANNELSER PÅ AAU
#         </span>
#         <style>
#          .link:hover {
# 		color: FFFFF;
# 	}
#
# 	.color .link:hover{
# 		color: FFFFF;
# 	}
#         </style>
#         <ul class="unstyled">
#          <li>
#           <a class="inlineBlock link" href="/uddannelser/bachelor/" title="Bacheloruddannelser på Aalborg Universitet → Læs mere her.">
#            <h3 class="hasArrow">
#             bacheloruddannelser
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock link" href="/uddannelser/kandidat/" title="Kandidatuddannelser på Aalborg Universitet">
#            <h3 class="hasArrow">
#             Kandidatuddannelser
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock link" href="/ingenioeruddannelser/" title="Ingeniøruddannelserne → Tilmeld dig ingeniørstudiet på AAU">
#            <h3 class="hasArrow">
#             Ingeniøruddannelser
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock link" href="/uddannelser/efteruddannelse/" title="Efteruddannelser på Aalborg Universitet">
#            <h3 class="hasArrow">
#             efteruddannelse
#            </h3>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="section">
#         <div class="spotCon grid g6">
#          <div class="circle white">
#           <a href="/pressen/" title="For pressen">
#            For Pressen
#           </a>
#          </div>
#         </div>
#         <div class="spotCon grid g6">
#          <div class="circle white">
#           <a href="https://vbn.aau.dk/da/persons/" title="Find en forsker på Aalborg Universitet">
#            Find forsker
#           </a>
#          </div>
#         </div>
#         <div class="clear">
#         </div>
#        </div>
#       </div>
#       <div class="clear cleargrid">
#       </div>
#      </div>
#      <div class="section">
#       <div class="spotCon grid g4">
#        <div class="article" itemscope="" itemtype="http://schema.org/Article">
#         <div class="box white">
#          <h2 itemprop="headline">
#           Bæredygtighed
#          </h2>
#          <a href="https://www.aau.dk/om-aau/baeredygtighed/">
#           <img alt="Læs om bæredygtighed på AAU" itemprop="image" src="/digitalAssets/724/724794_img_6651_edit.jpg" title="Læs om bæredygtighed på AAU">
#           </img>
#          </a>
#          <meta content="2021-12-17T08:47+0100" itemprop="dateModified"/>
#          <meta content="2020-01-17T09:44+0100" itemprop="datePublished"/>
#          <div itemprop="articleBody">
#           <p>
#            Se hvordan Aalborg Universitet arbejder med bæredygtighed i forskning, uddannelse, samarbejde og den daglige drift.
#            <br>
#             <br/>
#             <a class="smallButton" href="/om-aau/baeredygtighed/">
#              Læs om Bæredygtighed på AAU
#             </a>
#            </br>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="spotCon grid g4">
#        <div class="article" itemscope="" itemtype="http://schema.org/Article">
#         <div class="box white">
#          <h2 itemprop="headline">
#           Kandidatansøgninger
#          </h2>
#          <meta content="2021-12-17T08:47+0100" itemprop="dateModified"/>
#          <meta content="2021-01-15T07:55+0100" itemprop="datePublished"/>
#          <div itemprop="articleBody">
#           <p>
#            <img alt="" src="/digitalAssets/941/941740_aau_human_240619_00517-650px.png" style=""/>
#           </p>
#           <p>
#            Ansøgningsfristen er den 1.marts, hvis du ønsker at starte på AAU på en kandidatuddannelse den 1.september 2022.
#            <br/>
#           </p>
#           <p>
#            <a class="smallButton" href="https://www.aau.dk/uddannelser/optagelse/kandidat/ansoegning-og-frister">
#             Se ansøgningsproceduren
#            </a>
#           </p>
#           <p>
#            <a class="smallButton" href="https://www.aau.dk/uddannelser/kandidat">
#             Se AAU's kandidatuddannelser
#            </a>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="spotCon grid g4">
#        <div class="section">
#         <div class="spotCon grid g6">
#         </div>
#         <div class="spotCon grid g6">
#         </div>
#         <div class="clear">
#         </div>
#        </div>
#       </div>
#       <div class="clear cleargrid">
#       </div>
#      </div>
#      <div class="section">
#       <div class="spotCon grid g12">
#       </div>
#       <div class="clear cleargrid">
#       </div>
#      </div>
#      <div class="section">
#       <div class="spotCon grid g4">
#       </div>
#       <div class="spotCon grid g4">
#       </div>
#       <div class="spotCon grid g4">
#       </div>
#       <div class="clear cleargrid">
#       </div>
#      </div>
#      <div class="section">
#       <div class="spotCon grid g4">
#       </div>
#       <div class="spotCon grid g4">
#       </div>
#       <div class="spotCon grid g4">
#       </div>
#       <div class="clear cleargrid">
#       </div>
#      </div>
#      <div class="section">
#       <div class="spotCon grid g12">
#        <div class="article" itemscope="" itemtype="http://schema.org/Article">
#         <div class="box white">
#          <h2 itemprop="headline">
#           Nyheder og presse, arrangementer og ledige stillinger
#          </h2>
#          <meta content="2016-09-01T02:48+0200" itemprop="dateModified"/>
#          <meta content="2016-06-22T09:04+0200" itemprop="datePublished"/>
#         </div>
#        </div>
#       </div>
#       <div class="clear cleargrid">
#       </div>
#      </div>
#      <div class="section">
#       <div class="spotCon grid g4">
#        <div class="box white">
#         <h2>
#          Nyheder og Presse
#         </h2>
#         <ul class="group columned">
#          <li itemscope="" itemtype="http://schema.org/Article">
#           <a class="hasArrowBelow" href="https://www.nyheder.aau.dk/2021/nyhed/stoette-til-grundforskning-i-litteratur-og-kreativitet.cid527279" itemprop="url" title="">
#            <p class="muted">
#             13.12.2021
#            </p>
#            <h3 itemprop="name">
#             Støtte til grundforskning i litteratur og kreativitet
#            </h3>
#           </a>
#           <meta content="2021-12-13T10:33+0100" itemprop="datePublished"/>
#          </li>
#          <li itemscope="" itemtype="http://schema.org/Article">
#           <a class="hasArrowBelow" href="https://www.nyheder.aau.dk/2021/nyhed/tidligere-aau-studerende-faar-pris-for-medvirken-til-kickstart-af-costa-ricas-klimastrategi.cid524638" itemprop="url" title="">
#            <p class="muted">
#             29.10.2021
#            </p>
#            <h3 itemprop="name">
#             Tidligere AAU-studerende får pris for medvirken til kickstart af Costa Ricas klimastrategi
#            </h3>
#           </a>
#           <meta content="2021-10-29T04:26+0200" itemprop="datePublished"/>
#          </li>
#          <li itemscope="" itemtype="http://schema.org/Article">
#           <a class="hasArrowBelow" href="https://www.nyheder.aau.dk/2021/nyhed/femte-aar-i-traek--aau-er-europas-bedste-ingenioeruniversitet.cid524468" itemprop="url" title="">
#            <p class="muted">
#             28.10.2021
#            </p>
#            <h3 itemprop="name">
#             Femte år i træk: AAU er Europas bedste ingeniøruniversitet
#            </h3>
#           </a>
#           <meta content="2021-10-28T08:38+0200" itemprop="datePublished"/>
#          </li>
#         </ul>
#         <a class="smallButton expandableAddon" href="https://www.nyheder.aau.dk/">
#          Se listen
#         </a>
#        </div>
#       </div>
#       <div class="spotCon grid g4">
#        <div class="box white">
#         <h2>
#          Arrangementer
#         </h2>
#         <ul class="group columned">
#          <li itemscope="" itemtype="http://schema.org/Event">
#           <a class="hasArrowBelow" href="/arrangementer/vis/phd-defense-by-jaco-botha.cid527900" itemprop="url" title="">
#            <p class="muted">
#             11.01.2022 kl. 13.00 - 16.00
#            </p>
#            <h3 itemprop="name">
#             PhD defense by Jaco Botha
#            </h3>
#           </a>
#           <meta content="2022-01-11T04:00+0100" itemprop="endDate"/>
#           <meta content="2022-01-11T01:00+0100" itemprop="startDate"/>
#          </li>
#          <li itemscope="" itemtype="http://schema.org/Event">
#           <a class="hasArrowBelow" href="/arrangementer/vis/hvorfor-skal-du-have-en-bestyrelse--.cid525976" itemprop="url" title="">
#            <p class="muted">
#             13.01.2022 kl. 13.00 - 15.30
#            </p>
#            <h3 itemprop="name">
#             Hvorfor skal du have en bestyrelse?
#            </h3>
#           </a>
#           <meta content="2022-01-13T03:30+0100" itemprop="endDate"/>
#           <meta content="2022-01-13T01:00+0100" itemprop="startDate"/>
#          </li>
#          <li itemscope="" itemtype="http://schema.org/Event">
#           <a class="hasArrowBelow" href="/arrangementer/vis/forvaltningsretskonference-2022.cid410986" itemprop="url" title="">
#            <p class="muted">
#             18.01.2022 - 19.01.2022
#            </p>
#            <h3 itemprop="name">
#             Forvaltningsretskonference 2022
#            </h3>
#           </a>
#           <meta content="2022-01-19T04:30+0100" itemprop="endDate"/>
#           <meta content="2022-01-18T08:30+0100" itemprop="startDate"/>
#          </li>
#         </ul>
#         <a class="smallButton expandableAddon" href="/arrangementer/">
#          Se listen
#         </a>
#        </div>
#       </div>
#       <div class="spotCon grid g4">
#        <div class="article" itemscope="" itemtype="http://schema.org/Article">
#         <div class="box white">
#          <h2 itemprop="headline">
#           Ledige stillinger
#          </h2>
#          <a href="https://www.stillinger.aau.dk/">
#           <img alt="Grafik ledige stillinger på AAU" itemprop="image" src="/digitalAssets/221/221268_196006_phd-seminar.jpg" title="Grafik ledige stillinger på AAU">
#           </img>
#          </a>
#          <meta content="2021-04-15T12:22+0200" itemprop="dateModified"/>
#          <meta content="2016-08-29T01:47+0200" itemprop="datePublished"/>
#          <div itemprop="articleBody">
#           <p>
#            Som en vidensintensiv virksomhed ønsker vi at tiltrække de bedste faglige kompetencer. Hvis du har engagement og lyst til at gøre en forskel, er der gode muligheder for at skabe karriere og resultater i dit job på Aalborg Universitet.
#           </p>
#           <p>
#            <a class="smallButton" href="https://www.stillinger.aau.dk/">
#             Se ledige stillinger på AAU
#            </a>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="clear cleargrid">
#       </div>
#      </div>
#      <div class="section">
#       <div class="spotCon grid g4">
#        <div class="article" itemscope="" itemtype="http://schema.org/Article">
#         <div class="box white">
#          <h2 itemprop="headline">
#           KONTAKT AALBORG UNIVERSITET
#          </h2>
#          <meta content="2021-12-17T11:52+0100" itemprop="dateModified"/>
#          <meta content="2016-08-29T03:33+0200" itemprop="datePublished"/>
#          <div itemprop="articleBody">
#           <p>
#            Aalborg Universitet
#            <br/>
#            AAU's administration
#            <br/>
#            Fredrik Bajers Vej 7K
#            <br/>
#            9220 Aalborg Ø
#           </p>
#           <p>
#            Aalborg Universitet
#            <br/>
#            Postboks 159
#            <br/>
#            9100 Aalborg
#           </p>
#           <p>
#            Telefon: 9940 9940
#            <br/>
#            Mail:
#            <a class="none" href="mailto:aau@aau.dk">
#             aau@aau.dk
#            </a>
#           </p>
#           <p>
#            CVRnr: 29102384.
#            <a class="none" href="https://okonomi.aau.dk">
#             Se EANnr
#            </a>
#           </p>
#           <p>
#            <a class="none" href="https://www.facebook.com/AalborgUniversitet/">
#             <img alt="AAU på Facebook" src="/digitalAssets/221/221326_social_ikon-01-01.png" style=""/>
#            </a>
#            <a class="none" href="https://www.linkedin.com/school/aalborg-universitet/">
#             <img alt="AAU på LinkedIn" src="/digitalAssets/221/221329_social_ikon-01-04.png" style=""/>
#            </a>
#            <a class="none" href="https://www.instagram.com/aaustudieliv/" title="Instagram #AAUStudieliv">
#             <img alt="AAUstudieliv" src="/digitalAssets/221/221327_social_ikon-01-02.png" style=""/>
#            </a>
#            <a class="none" href="https://www.snapchat.com/add/aauuni" title="Snapchat AAUUni">
#             <img alt="Aalborg Universitet Snapchat aauuni" src="/digitalAssets/221/221328_social_ikon-01-03.png" style="" title="Aalborg Universitet Snapchat aauuni"/>
#            </a>
#           </p>
#           <ul>
#            <li>
#             <a class="none" href="/om-cookies/">
#              AAU's privatlivs- og cookiespolitik samt DPO
#             </a>
#             .
#            </li>
#            <li>
#             <a class="none" href="/kontakt/whistleblowerordning/">
#              Whistleblowerordning
#             </a>
#            </li>
#           </ul>
#           <p>
#            <br/>
#            <a class="smallButton" href="/kontakt/">
#             Kontakt AAU og find rundt
#            </a>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="spotCon grid g4">
#        <div class="article" itemscope="" itemtype="http://schema.org/Article">
#         <div class="box white">
#          <h2 itemprop="headline">
#           AAU – Viden for verden
#          </h2>
#          <meta content="2021-02-03T10:57+0100" itemprop="dateModified"/>
#          <meta content="2017-07-10T12:03+0200" itemprop="datePublished"/>
#          <div itemprop="articleBody">
#           <p>
#            <a href="https://www.aau.dk/om-aau">
#             <img alt="Sammen skaber vi viden for verden" src="/digitalAssets/951/951851_viden-for-verden.png" style="" title="Sammen skaber vi viden for verden"/>
#            </a>
#           </p>
#           <p>
#            <a class="none" href="/uddannelser/">
#             AAU’s uddannelser
#            </a>
#            og
#            <a class="none" href="/forskning/">
#             forskning
#            </a>
#            er problem- og projektbaserede og har fokus på det tværdisciplinære.
#           </p>
#           <p>
#            Gennem
#            <a class="none" href="/samarbejde/">
#             samarbejde
#            </a>
#            mellem forskere, studerende og offentlige og private virksomheder udbyder vi virkelighedsnære uddannelser og skaber forskningsresultater i verdensklasse.
#           </p>
#           <p>
#            Sådan opnår vi nye erkendelser, finder nye løsninger på samfundets problemer og skaber viden, der forandrer verden.
#           </p>
#           <p>
#            <a class="smallButton" href="https://www.aau.dk/om-aau">
#             Læs mere om AAU
#            </a>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="spotCon grid g4">
#        <div class="article" itemscope="" itemtype="http://schema.org/Article">
#         <div class="box white">
#          <h2 itemprop="headline">
#           ECIU
#          </h2>
#          <meta content="2021-02-03T10:55+0100" itemprop="dateModified"/>
#          <meta content="2017-06-22T11:38+0200" itemprop="datePublished"/>
#          <div itemprop="articleBody">
#           <p>
#            <img alt="" src="/digitalAssets/947/947272_eciu-logo-small.jpg"/>
#           </p>
#           <p>
#            Aalborg Universitet er medlem af European Consortium of Innovative Universities (ECIU) - et førende internationalt netværk af forskningsintensive universiteter med fælles vægt på innovation, kreativitet og samfundsmæssig effekt.
#           </p>
#           <p>
#            ECIU University er et initiativ i ECIU, der skaber en banebrydende og innovativ uddannelsesmodel.
#           </p>
#           <p>
#           </p>
#           <p>
#            <a class="smallButton" href="https://www.en.aau.dk/cooperation/international-cooperation/eciu">
#             Læs mere om ECIU og ECIU University
#            </a>
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="clear cleargrid">
#       </div>
#      </div>
#     </div>
#     <!-- end wrapper in Main -->
#    </div>
#    <!-- end Main -->
#    <div class="push">
#    </div>
#   </div>
#   <!--  end stickyFooter -->
#   <!--  Footer -->
#   <div class="footer spotCon section">
#    <div class="footerArrow">
#    </div>
#    <div class="footerInner">
#     <div class="wrapper">
#      <div class="section">
#       <div class="spotCon grid g4">
#        <div itemscope="" itemtype="http://schema.org/EducationalOrganization">
#         <div class="box white">
#          <p class="h2">
#           Kontakt AAU
#          </p>
#          <p class="h3">
#           <span itemprop="name">
#            Aalborg Universitet
#           </span>
#          </p>
#          <p>
#           AAU's administration
#           <br/>
#           <span itemprop="address" itemscope="" itemtype="http://schema.org/PostalAddress">
#            <span itemprop="streetAddress">
#             Fredrik Bajers Vej 7K
#            </span>
#            <br/>
#            <span itemprop="postalCode">
#             9220
#            </span>
#            <span itemprop="addressLocality">
#             Aalborg Ø
#            </span>
#            <br/>
#           </span>
#          </p>
#          <p>
#           Aalborg Universitet
#           <br/>
#           Postboks 159
#           <br/>
#           <span itemprop="postalCode">
#            9100
#           </span>
#           <span itemprop="addressLocality">
#            Aalborg
#           </span>
#           <br/>
#          </p>
#          <p>
#           Telefon:
#           <span itemprop="telephone">
#            9940 9940
#           </span>
#          </p>
#          <p>
#           Mail:
#           <span itemprop="email">
#            <a href="mailto:aau@aau.dk">
#             aau@aau.dk
#            </a>
#           </span>
#           <br/>
#           CVRnr: 29102384
#           <br/>
#           Eannr:
#           <a class="none" href="https://www.okonomi.aau.dk" target="_blank">
#            EANnr
#           </a>
#          </p>
#          <p>
#           <a href="https://www.aau.dk/om-websitet">
#            Om AAU's website (Feedback til webmaster)
#           </a>
#          </p>
#          <p>
#           <a href="https://www.aau.dk/om-cookies">
#            Privatlivspolitik, DPO og brug af cookies
#           </a>
#          </p>
#          <p>
#           <a href="https://www.adgangforalle.dk/">
#            Læs op
#           </a>
#           (få teksten på websitet læst op)
#          </p>
#         </div>
#        </div>
#       </div>
#       <div class="spotCon grid g4">
#        <div class="box white" style="">
#         <span class="h2">
#          Om AAU
#         </span>
#         <style>
#          .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#         </style>
#         <ul class="unstyled">
#          <li>
#           <a class="inlineBlock" href="https://www.aau.dk/om-aau/organisation" title="Organisation">
#            <h3 class="hasArrow">
#             Organisation
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock" href="https://www.aau.dk/om-aau/aalborg-modellen-problembaseret-laering" title="Problembaseret læring">
#            <h3 class="hasArrow">
#             Problembaseret læring
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock" href="https://www.aau.dk/om-aau/strategi-rammekontrakt" title="Strategi og udvikling">
#            <h3 class="hasArrow">
#             Strategi og udvikling
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock" href="https://www.aau.dk/om-aau/internationalt-samarbejde" title="Internationalt samarbejde">
#            <h3 class="hasArrow">
#             Internationalt samarbejde
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock" href="https://www.aau.dk/om-aau/historie-priser" title="Historie, priser og hæder">
#            <h3 class="hasArrow">
#             Historie, priser og hæder
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock" href="https://www.kvalitetssikring.aau.dk" title="Uddannelseskvalitet">
#            <h3 class="hasArrow">
#             Uddannelseskvalitet
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock" href="https://www.aau.dk/om-aau/aau-i-tal/" title="AAU i tal">
#            <h3 class="hasArrow">
#             AAU i tal
#            </h3>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="spotCon grid g4">
#        <div class="box white" style="">
#         <span class="h2">
#          AAU på de sociale medier
#         </span>
#         <style>
#          .link:hover {		color: ;	}		.color .link:hover{		color: ;	}
#         </style>
#         <ul class="unstyled">
#          <li>
#           <a class="inlineBlock" href="https://www.facebook.com/AalborgUniversitet" title="Aalborg Universitet på Facebook">
#            <h3 class="hasArrow">
#             Facebook
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock" href="https://www.linkedin.com/company/aalborg-university" title="Aalborg Universitet på LinkedIn">
#            <h3 class="hasArrow">
#             LinkedIn
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock" href="https://www.instagram.com/aaustudieliv" title="Aalborg Universitet på Instagram">
#            <h3 class="hasArrow">
#             Instagram
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock" href="https://www.snapchat.com/add/aauuni" title="Aalborg Universitet på Snapchat">
#            <h3 class="hasArrow">
#             Snapchat
#            </h3>
#           </a>
#          </li>
#          <li>
#           <a class="inlineBlock" href="https://www.youtube.com/aalborguniversitet" title="Aalborg Universitet på YouTube">
#            <h3 class="hasArrow">
#             YouTube
#            </h3>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="clear cleargrid">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--  end Footer -->
#   <script src="https://www.resources.aau.dk/design2013/resources/js/jquery.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.resources.aau.dk/design2013/resources/js/jquery.marquee.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.resources.aau.dk/design2013/resources/js/jquery.hoverIntent.minified.js" type="text/javascript">
#   </script>
#   <script src="https://www.resources.aau.dk/design2013/resources/js/selectivizr.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.resources.aau.dk/design2013/resources/js/jquery.carouFredSel-5.6.4-packed.js" type="text/javascript">
#   </script>
#   <script src="https://www.resources.aau.dk/design2013/resources/js/waypoint.js" type="text/javascript">
#   </script>
#   <script src="https://www.resources.aau.dk/design2013/resources/js/modernizr.custom.all.js" type="text/javascript">
#   </script>
#   <script src="https://www.resources.aau.dk/design2013/resources/js/jquery.cookie.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.resources.aau.dk/design2013/resources/js/print.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.resources.aau.dk/design2013/resources/js/script.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.resources.aau.dk/design2013/resources/js/jquery.fancybox.min.js" type="text/javascript">
#   </script>
#   <script src="https://www.resources.aau.dk/design2013/resources/js/studyGuideSearch.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function() {
# 			$(".fancybox").fancybox({
# 				maxWidth	: 800,
# 				maxHeight	: 600,
# 				fitToView	: false,
# 				width		: "70%",
# 				height		: "70%",
# 				helpers : {
# 			        overlay : {
# 			            css : {
# 			                "background" : "rgba(0, 0, 0, 0.5)"
# 			            }
# 			        }
# 			    }
# 			});
# 		});
#   </script>
#  </body>
# </html>

# %% [markdown]
# We can get the title:

# %%
print(r_parse.find('title'))
print(r_parse.find('title').string)
# Out:
# <title>AAU - Viden for verden</title>
# AAU - Viden for verden

# %% [markdown]
# Importantly, we can get all the links on the page. The following also illustrates the sleep() function to implement time delays (the following will take a while to complete; use the "interrupt kernel" button to terminate early):

# %%
for a in r_parse.find_all('a'):
    sleep(1)
    print(a['href'])
# Out:
# https://www.aau.dk/nyheder
# https://www.aau.dk/arrangementer
# https://www.aau.dk/kontakt
# https://www.aau.dk/om-aau/organisation/campus
# https://www.aau.dk/pressen
# https://www.alumni.aau.dk/
# #
# https://www.aau.dk/nyheder
# https://www.aau.dk/arrangementer
# https://www.aau.dk/kontakt
# https://www.aau.dk/om-aau/organisation/campus
# https://www.aau.dk/pressen
# https://www.alumni.aau.dk/
# https://www.aau.dk/uddannelser/
# https://www.aau.dk/forskning/
# https://www.aau.dk/samarbejde/
# https://www.aau.dk/om-aau/
# https://www.stillinger.aau.dk/
# https://www.intern.aau.dk/
# https://www.search.aau.dk/?locale=da
# https://www.en.aau.dk/
# https://www.search.aau.dk/?locale=da
# https://www.en.aau.dk/
# https://www.aau.dk
# #
# https://www.aau.dk/uddannelser/
# https://www.aau.dk/uddannelser/bachelor
# https://www.aau.dk/uddannelser/kandidat
# https://www.aau.dk/uddannelser/sidefag-tilvalgsfag
# https://www.aau.dk/uddannelser/bliv-gymnasielaerer
# https://www.evu.aau.dk
# https://www.aau.dk/uddannelser/optagelse/bachelor
# http://www.adgangstjekker.aau.dk
# https://www.aau.dk/uddannelser/optagelse/kandidat/
# https://www.aau.dk/uddannelser/optagelse/indskrivning-gaestestuderende-studieskift
# https://www.aau.dk/uddannelser/optagelse/adgangskursus
# https://www.aau.dk/uddannelser/optagelse/Optagelsesvejledning/
# https://www.aau.dk/uddannelser/moed-aau
# https://www.aau.dk/uddannelser/gruppe-og-projektarbejde
# https://www.aau.dk/uddannelser/her-kan-du-studere-paa-aau/aalborg
# https://www.aau.dk/uddannelser/her-kan-du-studere-paa-aau/esbjerg
# https://www.aau.dk/uddannelser/her-kan-du-studere-paa-aau/koebenhavn
# https://www.aau.dk/uddannelser/optagelse/
# https://www.aau.dk/uddannelser/studievejledning/
# https://www.aau.dk/uddannelser/studievejledning/studiets-vejledere
# https://www.aau.dk/uddannelser/su
# https://www.aau.dk/uddannelser/sps
# #
# https://www.aau.dk/forskning/
# https://vbn.aau.dk/da/publications/search.html
# https://vbn.aau.dk/da/projects/search.html
# https://vbn.aau.dk/da/persons/search.html?current=true
# https://vbn.aau.dk/da/clippings/
# https://www.aau.dk/forskning/forskningsenheder/institutter
# https://www.aau.dk/forskning/phd/phd-skoler
# https://vbn.aau.dk/da/organisations/?format=&type=%2Fdk%2Fatira%2Fpure%2Forganisation%2Forganisationtypes%2Forganisation%2Fknowledgecenter&nofollow=true
# https://www.strategi.aau.dk/Forskning
# https://www.aau.dk/forskning/open-access
# https://www.aau.dk/forskning/ranking
# https://www.stillinger.aau.dk/videnskabelige-stillinger/
# https://www.aau.dk/forskning/phd/
# https://www.aau.dk/forskning/phd/phd-skoler/
# https://www.stillinger.aau.dk/phd-stillinger/
# https://www.aau.dk/forskning/phd/soeg-phd/
# https://www.aau.dk/samarbejde/virksomheder/samarbejde-forskere/erhvervsphd
# #
# https://www.aau.dk/samarbejde/
# https://www.aau.dk/samarbejde/guide-samarbejde
# https://www.aau.dk/samarbejde/virksomheder/efter-videreuddannelse
# https://www.aau.dk/samarbejde/virksomheder/Erhvervsklynger
# https://www.aau.dk/samarbejde/virksomheder/find-medarbejdere
# https://www.aau.dk/samarbejde/virksomheder/profiler-virksomhed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24916/3150544074.py in <module>
#       1 for a in r_parse.find_all('a'):
# ----> 2     sleep(1)
#       3     print(a['href'])
#
# KeyboardInterrupt:

# %%
from queue import SimpleQueue as Queue
import random
from datetime import datetime
from datetime import timedelta


# Keep lists of visited pages and a result of urls and titles
visited = []
results = []

# Initialize frontier of 10 front queues that are assigned randomly
frontier = []
for i in range(4):
    frontier.append(Queue())

def enqueue(qlist, obj):
    q = random.choice(qlist)
    q.put(obj)



# Keep back queues as dictionary
backQ = {}

# Extract the next url crawl from back queues
def get_crawl(qd):
    result = None
    keys = list(qd)
    i = 0
    sec2 = timedelta(0,2)
    # Search through each back queue
    keys.sort(key=lambda x: qd[x]['time'])
    while result is None and i < len(keys):
        key = keys[i]
        if not qd[key]['queue'].empty() and datetime.now() > qd[key]['time']:
            # This queue is not empty and the timestamp permits
            result = qd[key]['queue'].get()
            # Update with new timestamp
            qd[key]['time'] = datetime.now() + sec2

        else:
            i += 1
    return result



# Approximate host domain
def extract_domain(url):
    s = url.split("/")
    return s[2]

# %%
# define start seed
seed = ["https://www.pinchofyum.com/", "https://www.loveandlemons.com/","https://www.imdb.com/", "https://www.gamegrumps.com/", "https://www.aau.dk/"]

# Put seeds in frontier
for s in seed:
    enqueue(frontier, s)

while len(results) < 1000:
    next_url = get_crawl(backQ)
    if not backQ or get_crawl(backQ) is None:
        # If all back queues are empty, refill by emptying front queues
        for f in frontier:
            while not f.empty():
                url = f.get()
                domain = extract_domain(url)
                if domain not in backQ.keys():
                    # Add new back queue if one for this domain does not exist
                    backQ[domain] = {'time': datetime.now(), 'queue': Queue()}
                backQ[domain]['queue'].put(url)

    else:
        try:
            # Logic for crawling a page
            if next_url in visited or next_url is None:
                continue
            print('crawling at ' + next_url)
            # Initialize robotfile parser
            rp=RobotFileParser()
            rp.set_url(next_url)
            rp.read()
            # Check if robots.txt allows
            if rp.can_fetch("*", next_url):
                r=requests.get(next_url)
                visited.append(next_url)
                #extract title
                r_parse = BeautifulSoup(r.text, 'html.parser')
                title = r_parse.find('title')
                if title is not None:
                    title = title.string
                    # save result
                    res = {'url': next_url, 'title': title}
                    results.append(res)
                    for a in r_parse.find_all('a'):
                        if 'href' in a.attrs:
                            l = a['href']
                            if l.startswith('https') and l not in visited:
                                enqueue(frontier, l)
            else:
                print('could not crawl at ' + next_url)
        except:
            print(f'woops at {next_url}')
# Out:
# crawling at https://www.loveandlemons.com/
# crawling at https://www.imdb.com/
# crawling at https://www.loveandlemons.com/easy-dinner-ideas/
# crawling at https://www.pinterest.com/loveandlemons/
# crawling at https://www.facebook.com/lovelemonsfood
# crawling at https://instagram.com/imdb
# crawling at https://help.imdb.com/imdb?ref_=cons_nb_hlp
# crawling at https://youtube.com/imdb/
# crawling at https://www.amazon.jobs/en/teams/imdb
# crawling at https://m.imdb.com/feature/bestpicture/?ref_=nv_ch_osc
# crawling at https://pro.imdb.com?ref_=cons_nb_hm&rf=cons_nb_hm
# crawling at https://facebook.com/imdb
# crawling at https://pro.imdb.com?ref_=cons_tf_pro&rf=cons_tf_pro
# crawling at https://www.imdb.com/search/
# crawling at https://help.imdb.com/article/imdb/general-information/why-do-i-need-to-enable-my-cookies-on-imdb/GWE3JQ8VUQDCFW3Q?ref_=helpsrall#
# crawling at https://slyb.app.link/SKdyQ6A449
# crawling at https://www.loveandlemons.com/thumbprint-cookies/
# crawling at https://instagram.com/loveandlemons/
# crawling at https://pro.imdb.com/?ref_=helpms_helphdr_pro
# crawling at https://www.amazon.jobs/teams/imdb?ref_=helpms_helpftr_jobs
# crawling at https://contribute.imdb.com/czone?ref_=nv_cm_cz
# crawling at https://www.pinterest.com/pin/create/bookmarklet/?url=https%3A%2F%2Fwww.loveandlemons.com%2Feasy-dinner-ideas%2F&media=https%3A%2F%2Fcdn.loveandlemons.com%2Fwp-content%2Fuploads%2F2019%2F09%2Fdinner-ideas-pin-2.jpg&description=&is_video=false
# crawling at https://m.imdb.com/chart/starmeter/?ref_=nv_cel_brn
# crawling at https://es-la.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Flovelemonsfood
# crawling at https://portal.facebook.com/
# crawling at https://about.facebook.com/
# crawling at https://policies.google.com/technologies/cookies?hl=da&utm_source=ucb
# crawling at https://pl-pl.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdb
# crawling at https://www.oculus.com/
# woops at https://www.oculus.com/
# crawling at https://ro-ro.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Flovelemonsfood
# crawling at https://www.linkedin.com/company/amazon?Amazon.jobs=footer
# could not crawl at https://www.linkedin.com/company/amazon?Amazon.jobs=footer
# crawling at https://tr-tr.facebook.com/login/?next=https%3A%2F%2Fwww.facebook.com%2Fimdb
# crawling at https://pay.facebook.com/
